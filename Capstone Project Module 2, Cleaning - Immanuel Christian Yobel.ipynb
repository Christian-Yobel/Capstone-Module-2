# %%
# import library
import numpy as np 
import pandas as pd

# visualization
import matplotlib.pyplot as plt 
import seaborn as sns 

# menampilkan semua kolom
pd.set_option('display.max_columns', None)

# menghilangkan warning
import warnings
warnings.filterwarnings('ignore')

# %%
#pd.set_option('display.max_rows', 140)

# %% [markdown]
# # **1. Introduction**

# %% [markdown]
# # **Business Understanding**
#
# ### **Context**
#
# Transjakarta is a Bus Rapid Transit (BRT) system serving the city of Jakarta, Indonesia. Launched in 2004, it was the first BRT system in Southeast Asia and South Asia. Transjakarta operates a network of bus lines throughout the city, using dedicated bus lanes to provide faster, more efficient public transportation. The system aims to reduce traffic congestion, improve air quality, and provide affordable transportation options for Jakarta's residents and visitors. Transjakarta uses a tap-in, tap-out system with smart cards for fare collection, allowing for detailed tracking of passenger journeys and system usage.
#
#
# ### **Problem statement**
#
# As Jakarta continues to grow and urbanize, efficient public transportation becomes increasingly crucial. Transjakarta plays a vital role in moving millions of people daily, but faces challenges in optimizing its service to meet the evolving needs of the city. With the availability of detailed transaction data, there's an opportunity to gain insights that can lead to significant improvements in service quality, operational efficiency, and passenger satisfaction.
#
#
# ### **Challenges and Opportunities for New Airbnb Partners**
#
# While Transjakarta has been successful in providing a much-needed transportation solution, it faces several challenges:
#
# **Route Performance**
#
# Challenge: Identifying the most and least used Transjakarta routes.
# Goal: Optimize resource allocation by potentially increasing services on popular routes and reviewing the necessity of less-used routes.
#
#
# **Stop Utilization**
#
# Challenge: Understanding which Transjakarta stops are most frequently used.
# Goal: Improve infrastructure and services at high-traffic stops to enhance passenger experience.
#
#
# **Demographic Analysis**
#
# Challenge: Analyzing usage patterns based on gender and age (birth decade).
# Goal: Tailor services and marketing strategies to cater to the primary user demographics.
#
#
# **Payment System Efficiency**
#
# Challenge: Identifying the most popular bank cards and analyzing fare distribution.
# Goal: Streamline payment processes and potentially negotiate better terms with frequently used banks.
#
#
# **Temporal Usage Patterns**
#
# Challenge: Understanding usage patterns throughout the day and peak hours.
# Goal: Adjust service frequency to match demand during different times of the day.
#
#
# **Journey Duration Analysis**
#
# Challenge: Analyzing the duration of passenger journeys.
# Goal: Identify opportunities to reduce travel times and improve service efficiency.
#
#
#
#
# ### **Goal: Guiding New Partners for Success**
#
# Through this data analysis project, we aim to answer the following question:
#
# **What key recommendations can be provided to Transjakarta to improve its service quality, operational efficiency, and meet the evolving transportation needs of Jakarta's residents?
# **
#
# By providing data-driven recommendations, we can help Transjakarta optimize its operations, enhance the passenger experience, and contribute to a more sustainable and efficient transportation system for Jakarta. This, in turn, will support the city's goals for reduced congestion, improved air quality, and enhanced mobility for its citizens.

# %% [markdown]
# # **2. Data Preparation**

# %% [markdown]
# Before beginning the analysis, we need to carry out data understanding and data cleaning simultaneously. The data understanding phase helps us explore the dataset's characteristics, such as identifying unique values, data types, duplicates, missing values, outliers, and anomalies. As these issues are recognized, we immediately address them in the data cleaning phase, which involves handling duplicates, missing values, and anomalies. I won't seperate these into 2 different subpart because i'll clean the data straight after i understand where the data is lacking. So both the Data Understanding and Data Cleaning will both be called Data Preparation

# %% [markdown]
# ## **Dataset and libraries**

# %% [markdown]
# There are 22 columns. The description of each column from Transjakarta.csv dataset can be seen as below
#
# |Column name | Descriptions|
# |---|------------------------|
# |**transID**     | Unique transaction id for every transaction|
# |**payCardID**   | Customers main identifier. The card customers use as a ticket for entrance and exit.|
# |**payCardBank**| Customers card bank issuer name|
# |**payCardName**| Customers name that is embedded in the card. |
# |**payCardSex**| Customers sex that is embedded in the card|
# |**payCardBirthDate**| Customers birth year|
# |**corridorID**| Corridor ID / Route ID as key for route grouping. |
# |**corridorName**| Corridor Name / Route Name contains Start and Finish for each route. |
# |**direction**| 0 for Go, 1 for Back. Direction of the route. |
# |**tapInStops**| Tap In (entrance) Stops ID for identifying stops name |
# |**tapInStopsName**| Tap In (entrance) Stops Name where customers tap in. |
# |**tapInStopsLat**| Latitude of Tap In Stops.|
# |**tapInStopsLon**| Longitude of Tap In Stops.|
# |**stopStartSeq**| Sequence of the stops, 1st stop, 2nd stops etc. Related to direction..|
# |**tapInTime**| Time of tap in. Date and time|
# |**tapOutStops**     | Tap Out (Exit) Stops ID for identifying stops name|
# |**tapOutStopsName**   | Tap out (exit) Stops Name where customers tap out|
# |**tapOutStopsLat**| Latitude of Tap Out Stops|
# |**tapOutStopsLon**| Longitude of Tap Out Stops |
# |**stopEndSeq**   | Sequence of the stops, 1st stop, 2nd stops etc. Related to direction.|
# |**tapOutTime**| Time of tap out. Date and time|
# |**payAmount**| The number of what customers pay. Some are free. Some not.|

# %%
transjakarta = pd.read_csv('Transjakarta.csv')
transjakarta
# Out:
#               transID            payCardID payCardBank  \
# 0      EIIW227B8L34VB      180062659848800      emoney
# 1      LGXO740D2N47GZ     4885331907664776         dki
# 2      DJWR385V2U57TO     4996225095064169         dki
# 3      JTUZ800U7C86EH         639099174703       flazz
# 4      VMLO535V7F95NJ         570928206772       flazz
# ...               ...                  ...         ...
# 37895  ZWEC949B8Q87QG  4685818286724028395      brizzi
# 37896  YHHK837P6Y95GN     6502902290603767         dki
# 37897  YXPP627N4G95HO      213159426675861      emoney
# 37898  RGVK175U2U98UV      377840859133591      emoney
# 37899  FMZZ963S4B68ZP         501862539795       flazz
#
#                   payCardName payCardSex  payCardBirthDate corridorID  \
# 0              Bajragin Usada          M              2008          5
# 1                Gandi Widodo          F              1997         6C
# 2               Emong Wastuti          F              1992        R1A
# 3                Surya Wacana          F              1978        11D
# 4             Embuh Mardhiyah          M              1982         12
# ...                       ...        ...               ...        ...
# 37895         Kamila Mahendra          F              2004         6B
# 37896            Titi Siregar          M              1974         9N
# 37897  drg. Zahra Nashiruddin          F              1976         1T
# 37898            Ana Agustina          M              1976     JAK.13
# 37899       drg. Leo Najmudin          F              1985         13
#
#                                    corridorName  direction tapInStops  \
# 0                         Matraman Baru - Ancol        1.0     P00142
# 1      Stasiun Tebet - Karet via Patra Kuningan        0.0    B01963P
# 2                            Pantai Maju - Kota        0.0    B00499P
# 3           Pulo Gebang - Pulo Gadung 2 via PIK        0.0    B05587P
# 4                         Tanjung Priok - Pluit        0.0     P00239
# ...                                         ...        ...        ...
# 37895         Ragunan - MH Thamrin via Semanggi        1.0     P00261
# 37896                    Pinang Ranti - Pramuka        1.0     P00064
# 37897                      Cibubur - Balai Kota        1.0    B02873P
# 37898               Tanah Abang - Jembatan Lima        1.0    B02505P
# 37899                         Ciledug - Tendean        0.0     P00001
#
#                tapInStopsName  tapInStopsLat  tapInStopsLon  stopStartSeq  \
# 0                   Pal Putih      -6.184631      106.84402             7
# 1                  Kemenkes 2      -6.228700      106.83302            13
# 2                Gg. Kunir II      -6.133132      106.81435            38
# 3                Taman Elok 1      -6.195743      106.93526            23
# 4      Sunter Boulevard Barat      -6.149650      106.88900             5
# ...                       ...            ...            ...           ...
# 37895                  Tosari      -6.196892      106.82309             2
# 37896       Garuda Taman Mini      -6.290154      106.88116             1
# 37897           Plaza Sentral      -6.216247      106.81676            12
# 37898          Museum Textile      -6.188656      106.80954            33
# 37899              Adam Malik      -6.236466      106.74786             2
#
#                  tapInTime tapOutStops        tapOutStopsName  tapOutStopsLat  \
# 0      2023-04-03 05:21:44      P00253                Tegalan       -6.203101
# 1      2023-04-03 05:42:44     B03307P    Sampoerna Strategic       -6.217152
# 2      2023-04-03 05:59:06     B04962P  Simpang Kunir Kemukus       -6.133731
# 3      2023-04-03 05:44:51     B03090P      Raya Penggilingan       -6.183068
# 4      2023-04-03 06:17:35      P00098       Kali Besar Barat       -6.135355
# ...                    ...         ...                    ...             ...
# 37895  2023-04-21 18:18:37      P00228                 SMK 57       -6.290967
# 37896  2023-04-18 21:52:31      P00179           Pinang Ranti       -6.291075
# 37897  2023-04-04 10:29:47     B00226P        Buperta Cibubur       -6.370321
# 37898  2023-04-15 19:59:26     B01787P             JPO Blok G       -6.188861
# 37899  2023-04-12 21:08:12      P00106         Kebayoran Lama       -6.238340
#
#        tapOutStopsLon  stopEndSeq           tapOutTime  payAmount
# 0           106.85715        12.0  2023-04-03 06:00:53     3500.0
# 1           106.81892        21.0  2023-04-03 06:40:01     3500.0
# 2           106.81475        39.0  2023-04-03 06:50:55     3500.0
# 3           106.93194        29.0  2023-04-03 06:28:16     3500.0
# 4           106.81143        15.0  2023-04-03 06:57:03     3500.0
# ...               ...         ...                  ...        ...
# 37895       106.82365        13.0  2023-04-21 19:55:49     3500.0
# 37896       106.88634         2.0  2023-04-18 22:28:22     3500.0
# 37897       106.89628        14.0  2023-04-04 13:27:25    20000.0
# 37898       106.81135        34.0  2023-04-15 20:27:50        0.0
# 37899       106.77752         7.0  2023-04-12 21:34:53     3500.0
#
# [37900 rows x 22 columns]

# %%
# Displaying the summary of the dataset
transjakarta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37900 entries, 0 to 37899
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transID           37900 non-null  object
#  1   payCardID         37900 non-null  int64
#  2   payCardBank       37900 non-null  object
#  3   payCardName       37900 non-null  object
#  4   payCardSex        37900 non-null  object
#  5   payCardBirthDate  37900 non-null  int64
#  6   corridorID        36643 non-null  object
#  7   corridorName      35970 non-null  object
#  8   direction         37900 non-null  float64
#  9   tapInStops        36687 non-null  object
#  10  tapInStopsName    37900 non-null  object
#  11  tapInStopsLat     37900 non-null  float64
#  12  tapInStopsLon     37900 non-null  float64
#  13  stopStartSeq      37900 non-null  int64
#  14  tapInTime         37900 non-null  object
#  15  tapOutStops       35611 non-null  object
#  16  tapOutStopsName   36556 non-null  object
#  17  tapOutStopsLat    36556 non-null  float64
#  18  tapOutStopsLon    36556 non-null  float64
#  19  stopEndSeq        36556 non-null  float64
#  20  tapOutTime        36556 non-null  object
#  21  payAmount         36893 non-null  float64
# dtypes: float64(7), int64(3), object(12)
# memory usage: 6.4+ MB

# %%
# Checking the total of NA in our data
transjakarta.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1257
# corridorName        1930
# direction              0
# tapInStops          1213
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %%
# Checking dupilicated data
transjakarta.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# We will be making a table with complete dtype, unique, and nunique of each columns so that we can get a generalized view of our data

# %%
# Shortening the name for faster and easier code writing
tj = transjakarta

columns = [i for i in tj.columns]
nunique = [tj[i].nunique() for i in tj.columns]
dtype = [tj[i].dtype for i in tj.columns]
unique = [tj[i].unique() for i in tj.columns]

pd.set_option('display.max_colwidth', 300)
data_values = pd.DataFrame({
    'columns' : columns,
    'data type' : dtype,
    'nunique' : nunique,
    'unique' : unique
})

data_values
# Out:
#              columns data type  nunique  \
# 0            transID    object    37900
# 1          payCardID     int64     2000
# 2        payCardBank    object        6
# 3        payCardName    object     1993
# 4         payCardSex    object        2
# 5   payCardBirthDate     int64       67
# 6         corridorID    object      221
# 7       corridorName    object      216
# 8          direction   float64        2
# 9         tapInStops    object     2570
# 10    tapInStopsName    object     2602
# 11     tapInStopsLat   float64     2587
# 12     tapInStopsLon   float64     2458
# 13      stopStartSeq     int64       67
# 14         tapInTime    object    37079
# 15       tapOutStops    object     2230
# 16   tapOutStopsName    object     2248
# 17    tapOutStopsLat   float64     2237
# 18    tapOutStopsLon   float64     2139
# 19        stopEndSeq   float64       74
# 20        tapOutTime    object    35908
# 21         payAmount   float64        3
#
#                                                                                                                                                                                                                                                                                                          unique
# 0   [EIIW227B8L34VB, LGXO740D2N47GZ, DJWR385V2U57TO, JTUZ800U7C86EH, VMLO535V7F95NJ, DDES630K2F80KC, HEMW326B9N91TV, XTKE052E5E87LN, OIHS248V7S72EB, ERXO372B2H63RB, CLWK627W2M22WO, IIEK980X1O23NZ, OPLW560U3S06UG, XESX233R4U46DN, LZFD368Q3E81HJ, KLUN542I2F21PI, XDMP644Z5Y29DB, CUPO258C0D42PY, SBPQ144...
# 1   [180062659848800, 4885331907664776, 4996225095064169, 639099174703, 570928206772, 2251412124634980, 213155822653833, 3587341902618993, 6510013988638519, 3580401035990896, 5541851157087967, 347204308990092, 3536759468239783, 6575130739600630, 4056836188316, 4532407180860336, 4556326832434362836, ...
# 2                                                                                                                                                                                                                                                                     [emoney, dki, flazz, online, brizzi, bni]
# 3   [Bajragin Usada, Gandi Widodo, Emong Wastuti, Surya Wacana, Embuh Mardhiyah, Tirta Siregar, R. Devi Hariyah, S.T., Darmanto Rajasa, Cagak Maheswara, S.Sos, T. Dadap Pradana, M.Ak, Oskar Widiastuti, S.Farm, R.M. Labuh Laksmiwati, Shakila Maryadi, Danuja Usada, Nadine Utami, H. Lutfan Nurdiyanti, ...
# 4                                                                                                                                                                                                                                                                                                        [M, F]
# 5   [2008, 1997, 1992, 1978, 1982, 1993, 1974, 1991, 2004, 1984, 1988, 2002, 1975, 2011, 2003, 1981, 2009, 1983, 1999, 2007, 1979, 1960, 1995, 2001, 1990, 1968, 1985, 2010, 1989, 2006, 1986, 1965, 2005, 1966, 1994, 1972, 1969, 1970, 2000, 1953, 1977, 2012, 1987, 1996, 1971, 1956, 1980, 1998, 1973, 1...
# 6   [5, 6C, R1A, 11D, 12, 1T, JAK.18, nan, B14, 1Q, 5M, M7B, 9A, 4, JAK.46, S22, 13, 9E, M9, JAK.88, T11, JAK.16, 6V, 11Q, JAK.02, 11, 1C, 3B, M1, 7E, 1P, 7D, 6H, 14, BW9, JIS3, 2, JAK.15, 6N, M11, JAK.112, 9N, JAK.43B, JAK.42, 7P, JAK.36, 13B, JAK.06, JAK.14, M7, T21, 12A, 9D, 1, 3A, 3C, M8, B21, J...
# 7   [Matraman Baru - Ancol, Stasiun Tebet - Karet via Patra Kuningan, Pantai Maju - Kota, Pulo Gebang - Pulo Gadung 2 via PIK, Tanjung Priok - Pluit, Cibubur - Balai Kota, Kalibata - Kuningan, nan, Bekasi Barat - Kuningan, Rempoa - Blok M, Kampung Melayu - Tanah Abang via Cikini, BKN - Blok M, PGC 2...
# 8                                                                                                                                                                                                                                                                                                    [1.0, 0.0]
# 9   [P00142, B01963P, B00499P, B05587P, P00239, B00127P, B00243P, B03416P, B00795P, B05781P, B05433P, P00254, P00281, P00159, B00608P, B05291P, P00096, B00058P, P00093, B00722P, P00206, nan, P00259, B02335P, B05023P, P00233, B05833P, B06299P, B06040P, P00183, B00001P, B02831P, B00102P, P00039, P0012...
# 10  [Pal Putih, Kemenkes 2, Gg. Kunir II, Taman Elok 1, Sunter Boulevard Barat, Benhil 3, Cervino Village, SDN Pondok Labu 11, Imperium, TPU Bungur, Pegangsaan Timur, Tendean, Slipi Petamburan Arah Selatan, Pasar Rumput, Gelanggang Remaja Pasar Minggu, SMK Darussalam, JORR, Apartemen Simprug Teras, ...
# 11  [-6.184631, -6.2287, -6.133132, -6.195743, -6.14965, -6.21601, -6.224355, -6.313269, -6.210363, -6.247208, -6.199263, -6.240213, -6.201948, -6.207125, -6.284615, -6.319946, -6.236104, -6.232197, -6.133383, -6.137032, -6.184489, -6.270835, -6.239207, -6.229704, -6.238658, -6.215601, -6.258469, -6...
# 12  [106.84402, 106.83302, 106.81435, 106.93526, 106.889, 106.81632, 106.85165, 106.80221, 106.83059, 106.77889, 106.84205, 106.83102, 106.79998, 106.84112, 106.83787, 106.74598, 106.75488, 106.78874, 106.79267, 106.83254, 106.79674, 106.86741, 106.80777, 106.8962, 106.899461, 106.86805, 106.76529, ...
# 13                                           [7, 13, 38, 23, 5, 3, 25, 2, 1, 15, 17, 12, 4, 10, 19, 20, 6, 18, 28, 0, 16, 11, 9, 41, 14, 29, 40, 8, 45, 26, 48, 42, 21, 46, 34, 32, 22, 35, 47, 31, 30, 39, 24, 44, 52, 56, 36, 27, 33, 50, 37, 61, 43, 51, 54, 62, 58, 57, 65, 49, 64, 63, 55, 66, 59, 53, 68]
# 14  [2023-04-03 05:21:44, 2023-04-03 05:42:44, 2023-04-03 05:59:06, 2023-04-03 05:44:51, 2023-04-03 06:17:35, 2023-04-03 05:08:01, 2023-04-03 06:58:21, 2023-04-03 06:44:24, 2023-04-03 06:01:44, 2023-04-03 05:57:47, 2023-04-03 06:32:28, 2023-04-03 06:22:10, 2023-04-03 06:15:04, 2023-04-03 06:12:14, 2...
# 15  [P00253, B03307P, B04962P, B03090P, P00098, B00694P, nan, B00899P, B01853P, B06578P, B02387P, P00129, P00216, P00135, B01062P, B03032P, P00001, P00155, P00145, B05989P, B05720P, B01393P, P00133, B05256P, B03135P, P00086, B00147P, B02195P, B03322P, P00104, B02868P, B00221P, P00121, B03885P, B0247...
# 16  [Tegalan, Sampoerna Strategic, Simpang Kunir Kemukus, Raya Penggilingan, Kali Besar Barat, Grand Sahid, nan, Jln. Baros, Kayuringin 2, Blok M Jalur 3, Matraman 4, Mampang Prapatan, Semanggi, Matraman 2, Jln. Gabus Raya, Pusdiklat Kemenag 1, Adam Malik, Pasar Kebayoran Lama, Pancoran Tugu Arah Ba...
# 17  [-6.203101, -6.217152, -6.133731, -6.183068, -6.135355, -6.210975, nan, -6.311046, -6.245948, -6.243426, -6.199782, -6.242699, -6.22111, -6.19891, -6.301222, -6.312075, -6.236466, -6.238413, -6.2433, -6.12481, -6.172859, -6.28435, -6.236483, -6.228401, -6.232262, -6.221412, -6.257977, -6.140548,...
# 18  [106.85715, 106.81892, 106.81475, 106.93194, 106.81143, 106.82059, nan, 106.784, 106.99247, 106.80188, 106.8545, 106.82572, 106.81354, 106.83623, 106.75228, 106.74786, 106.78323, 106.84388, 106.81983, 106.66501, 106.85293, 106.79845, 106.88494, 106.91019, 106.86807, 106.75969, 106.73011, 106.789...
# 19  [12.0, 21.0, 39.0, 29.0, 15.0, 6.0, nan, 16.0, 24.0, 23.0, 14.0, 4.0, 17.0, 3.0, 11.0, 20.0, 36.0, 13.0, 5.0, 7.0, 8.0, 30.0, 19.0, 50.0, 10.0, 2.0, 22.0, 18.0, 33.0, 41.0, 44.0, 47.0, 1.0, 9.0, 34.0, 27.0, 25.0, 28.0, 37.0, 49.0, 35.0, 40.0, 31.0, 32.0, 51.0, 53.0, 26.0, 59.0, 42.0, 56.0, 43.0,...
# 20  [2023-04-03 06:00:53, 2023-04-03 06:40:01, 2023-04-03 06:50:55, 2023-04-03 06:28:16, 2023-04-03 06:57:03, 2023-04-03 05:52:25, nan, 2023-04-03 07:11:43, 2023-04-03 06:51:12, 2023-04-03 07:23:54, 2023-04-03 06:50:21, 2023-04-03 07:08:31, 2023-04-03 07:07:35, 2023-04-03 06:09:17, 2023-04-03 07:07:...
# 21                                                                                                                                                                                                                                                                                  [3500.0, 20000.0, 0.0, nan]

# %% [markdown]
# Based on the observation of unique values from data frame, we notice some finding such as,
# * There's only 2000 unique payCardID which means there's only 2000 unique cusomer from 37900 Transjakarta usage. This shows a huge reccuring usage from the cusomer in our data
# * There is more than 200 corridor ID which means there is more than 200 transjakarta route available
# * There should be equal number of corridorID and corridorName because each corridorName represents unique corridorID
# * There's more than 2500 tapInStops or Halte, with 220 route that make the number of average stops per route of 12
# * stopStartSeq represents Halte number, which means each stops have their own unique seqence number for their own route, based on the previous facts, this sequence is surprising because theres a route with more than 60 stops, which seems excessive and we'll be checking if the data is true
# * There is 4 different price which is wierd considering all Transjakarta usage should have the same price of 3500
# * We will also be changing the stopEndSeq to match the stopStartSeq which is an integer because every sequence must be an integer

# %%
# cheking the total number of sequence of each route
pd.pivot_table(tj,
               index = 'corridorID',
               values = 'stopStartSeq',
               aggfunc='max').sort_values('stopStartSeq', ascending= False).head(20)
# Out:
#             stopStartSeq
# corridorID
# JAK.33                68
# JAK.53                68
# JAK.58                66
# JAK.30                65
# JAK.110A              64
# JAK.56                61
# JAK.32                61
# JAK.18                58
# JAK.72                58
# JAK.31                56
# JAK.50                56
# JAK.12                55
# JAK.19                53
# JAK.14                53
# JAK.49                52
# JAK.17                51
# 5N                    50
# JAK.28                50
# JAK.29                50
# JAK.60                49

# %% [markdown]
# after crosschecking with transjakarta official website, transjakarta.co.id, turns out these route truly have such a high number of stops or sequence

# %% [markdown]
# Now We will use the corridorID to fill in the missing values in corridorName and vice versa. Before doing that, we need to ensure that the ID and Name are correct. corridorID and corridorName should have the same number of unique values because they are paired: a single corridorID represents a single corridorName. However, we found that there are 221 corridorIDs and only 216 corridorNames. We need to clean these values.

# %% [markdown]
# ## **MAKING DataFrame for LOOKUP condition : data_stasiun_count**

# %% [markdown]
# we will be using something functionally similar to a VLOOKUP or HLOOKUP from excel, so I'll be calling these pivot table where we match these table to the tj dataframe a "LOOKUP dataframe". This LOOKUP will be used for corridor Name and ID, If the ID is NA, then we will match the Name from TJ and LOOKUP and then fill the ID when we found the matching Name

# %%
# Making a pivot table, since the corridorName has lower count, there should be a corridorName with multiple corridorID
data_stasiun_count = pd.pivot_table(data = tj,
               index = ['corridorName','corridorID'],
               values = 'tapInStopsLat',
               aggfunc= 'count').sort_values(by=['tapInStopsLat'], ascending=False).reset_index().rename(columns={'tapInStopsLat': 'Used'})

data_stasiun_count
# Out:
#                                        corridorName corridorID  Used
# 0                              Cibubur - Balai Kota         1T   391
# 1                                     Ciputat - CSW        S21   383
# 2           Harmoni - Jakarta International Stadium       JIS3   337
# 3                      Kebayoran Lama - Tanah Abang         8C   333
# 4                    Kampung Rambutan - Pondok Gede     JAK.06   329
# ..                                              ...        ...   ...
# 216                         Gondangdia - Balai Kota         2Q    40
# 217                     Term. Pulo Gadung - Lampiri     JAK.99    31
# 218  Tanah Abang - Kebayoran Lama via Pos Pengumben     JAK.12    23
# 219                       Kampung Rambutan - Blok M         7B    16
# 220                           Matraman Baru - Ancol         M5    15
#
# [221 rows x 3 columns]

# %% [markdown]
# We will also be checking our previous questions of:
# * There should be equal number of corridorID and corridorName because each corridorName represents unique corridorID
#
# by looking at the duplicates

# %%
# Identify the corridorName values with more than one corridorID
duplicated_corridor = data_stasiun_count.groupby('corridorName')['corridorID'].count().reset_index()
duplicated_corridor = duplicated_corridor[duplicated_corridor['corridorID'] > 1]

# Filter the original DataFrame to get only the rows with duplicated corridorName values
data_stasiun_count[data_stasiun_count['corridorName'].isin(duplicated_corridor['corridorName'])]
# Out:
#                             corridorName corridorID  Used
# 14                   Pulo Gadung - Monas          2   279
# 26                 Matraman Baru - Ancol          5   246
# 39                         Blok M - Kota          1   230
# 59   Kalideres - Bundaran HI via Veteran         M3   204
# 114                 Pinang Ranti - Pluit         M9   149
# 152  Kalideres - Bundaran HI via Veteran          3   127
# 202                        Blok M - Kota         M1    61
# 205                  Pulo Gadung - Monas         M2    60
# 207                 Pinang Ranti - Pluit          9    59
# 220                Matraman Baru - Ancol         M5    15

# %% [markdown]
# After reviewing the Transjakarta Official Website transjakarta.co.id, it turns out that these 5 duplicated corridorIDs are correct. Transjakarta has different corridorIDs for these corridorNames.

# %% [markdown]
# ## **FILLING CorridorName and CorridorID with LAMBDA**

# %% [markdown]
# Now we will be matching the LOOKUP DataFrame with our tj DataFrame

# %%
def fill_missing_corridor(source, apply_to):
    # Create a dictionary for fast lookup
    id_to_name = dict(zip(data_stasiun_count[source], data_stasiun_count[apply_to]))
    
    # Fill missing 'corridorName' in tj using the dictionary
    tj[apply_to] = tj.apply(
        lambda row: id_to_name[row[source]] if pd.isna(row[apply_to]) and not pd.isna(row[source]) else row[apply_to],
        axis=1
    )
    
    return tj

fill_missing_corridor('corridorID', 'corridorName')
fill_missing_corridor('corridorName', 'corridorID')
# Out:
#               transID            payCardID payCardBank  \
# 0      EIIW227B8L34VB      180062659848800      emoney
# 1      LGXO740D2N47GZ     4885331907664776         dki
# 2      DJWR385V2U57TO     4996225095064169         dki
# 3      JTUZ800U7C86EH         639099174703       flazz
# 4      VMLO535V7F95NJ         570928206772       flazz
# ...               ...                  ...         ...
# 37895  ZWEC949B8Q87QG  4685818286724028395      brizzi
# 37896  YHHK837P6Y95GN     6502902290603767         dki
# 37897  YXPP627N4G95HO      213159426675861      emoney
# 37898  RGVK175U2U98UV      377840859133591      emoney
# 37899  FMZZ963S4B68ZP         501862539795       flazz
#
#                   payCardName payCardSex  payCardBirthDate corridorID  \
# 0              Bajragin Usada          M              2008          5
# 1                Gandi Widodo          F              1997         6C
# 2               Emong Wastuti          F              1992        R1A
# 3                Surya Wacana          F              1978        11D
# 4             Embuh Mardhiyah          M              1982         12
# ...                       ...        ...               ...        ...
# 37895         Kamila Mahendra          F              2004         6B
# 37896            Titi Siregar          M              1974         9N
# 37897  drg. Zahra Nashiruddin          F              1976         1T
# 37898            Ana Agustina          M              1976     JAK.13
# 37899       drg. Leo Najmudin          F              1985         13
#
#                                    corridorName  direction tapInStops  \
# 0                         Matraman Baru - Ancol        1.0     P00142
# 1      Stasiun Tebet - Karet via Patra Kuningan        0.0    B01963P
# 2                            Pantai Maju - Kota        0.0    B00499P
# 3           Pulo Gebang - Pulo Gadung 2 via PIK        0.0    B05587P
# 4                         Tanjung Priok - Pluit        0.0     P00239
# ...                                         ...        ...        ...
# 37895         Ragunan - MH Thamrin via Semanggi        1.0     P00261
# 37896                    Pinang Ranti - Pramuka        1.0     P00064
# 37897                      Cibubur - Balai Kota        1.0    B02873P
# 37898               Tanah Abang - Jembatan Lima        1.0    B02505P
# 37899                         Ciledug - Tendean        0.0     P00001
#
#                tapInStopsName  tapInStopsLat  tapInStopsLon  stopStartSeq  \
# 0                   Pal Putih      -6.184631      106.84402             7
# 1                  Kemenkes 2      -6.228700      106.83302            13
# 2                Gg. Kunir II      -6.133132      106.81435            38
# 3                Taman Elok 1      -6.195743      106.93526            23
# 4      Sunter Boulevard Barat      -6.149650      106.88900             5
# ...                       ...            ...            ...           ...
# 37895                  Tosari      -6.196892      106.82309             2
# 37896       Garuda Taman Mini      -6.290154      106.88116             1
# 37897           Plaza Sentral      -6.216247      106.81676            12
# 37898          Museum Textile      -6.188656      106.80954            33
# 37899              Adam Malik      -6.236466      106.74786             2
#
#                  tapInTime tapOutStops        tapOutStopsName  tapOutStopsLat  \
# 0      2023-04-03 05:21:44      P00253                Tegalan       -6.203101
# 1      2023-04-03 05:42:44     B03307P    Sampoerna Strategic       -6.217152
# 2      2023-04-03 05:59:06     B04962P  Simpang Kunir Kemukus       -6.133731
# 3      2023-04-03 05:44:51     B03090P      Raya Penggilingan       -6.183068
# 4      2023-04-03 06:17:35      P00098       Kali Besar Barat       -6.135355
# ...                    ...         ...                    ...             ...
# 37895  2023-04-21 18:18:37      P00228                 SMK 57       -6.290967
# 37896  2023-04-18 21:52:31      P00179           Pinang Ranti       -6.291075
# 37897  2023-04-04 10:29:47     B00226P        Buperta Cibubur       -6.370321
# 37898  2023-04-15 19:59:26     B01787P             JPO Blok G       -6.188861
# 37899  2023-04-12 21:08:12      P00106         Kebayoran Lama       -6.238340
#
#        tapOutStopsLon  stopEndSeq           tapOutTime  payAmount
# 0           106.85715        12.0  2023-04-03 06:00:53     3500.0
# 1           106.81892        21.0  2023-04-03 06:40:01     3500.0
# 2           106.81475        39.0  2023-04-03 06:50:55     3500.0
# 3           106.93194        29.0  2023-04-03 06:28:16     3500.0
# 4           106.81143        15.0  2023-04-03 06:57:03     3500.0
# ...               ...         ...                  ...        ...
# 37895       106.82365        13.0  2023-04-21 19:55:49     3500.0
# 37896       106.88634         2.0  2023-04-18 22:28:22     3500.0
# 37897       106.89628        14.0  2023-04-04 13:27:25    20000.0
# 37898       106.81135        34.0  2023-04-15 20:27:50        0.0
# 37899       106.77752         7.0  2023-04-12 21:34:53     3500.0
#
# [37900 rows x 22 columns]

# %%
transjakarta.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops          1213
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %% [markdown]
# After filling the NA with pivot table, there's still a lot of NA in the CorridorID and CorridorName, looking at it, there's only 221 rows of corridorName and ID combination from our pivot table, but when taking a data from transjakarta.co.id there's a 252 rows of corridorName and ID. In conclusion, there might be a corridorName without corridorID and vice versa from out tj dataframe. Now I'm trying to fill the NA with csv data from transjakarta.co.id

# %%
corridor = pd.read_csv('TJ corridor.csv', sep = ':')
corridor
# Out:
#     corridorID                               corridorName
# 0           1                               BLOK M - KOTA
# 1           2              PULO GADUNG - MONUMEN NASIONAL
# 2          2A                    PULO GADUNG - RAWA BUAYA
# 3           3    KALIDERES - MONUMEN NASIONAL VIA VETERAN
# 4          3F                KALIDERES - SENAYAN BANK DKI
# ..         ...                                        ...
# 247        M5                      KAMPUNG MELAYU - ANCOL
# 248        M6                        RAGUNAN - GALUNGGUNG
# 249        M7           KAMPUNG RAMBUTAN - KAMPUNG MELAYU
# 250        M8                    LEBAK BULUS - PASAR BARU
# 251        M9                        PINANG RANTI - PLUIT
#
# [252 rows x 2 columns]

# %% [markdown]
# The corridorName from the transjakarta website use all uppercase letter so we have to do the same to find a match with our LOOKUP dataframe

# %%
tj['corridorName'] = tj['corridorName'].fillna(
    tj['corridorID'].str.upper().map(corridor.set_index('corridorID')['corridorName'])
)

# %%
transjakarta.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops          1213
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %%
corridor.drop_duplicates(subset='corridorName', inplace= True)

# %%
tj['corridorID'] = tj['corridorID'].fillna(
    tj['corridorName'].str.upper().map(corridor.set_index('corridorName')['corridorID'])
)

# %%
transjakarta.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops          1213
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %% [markdown]
# Turns out using outside more complete data doesn really have any effect in filling the NA

# %% [markdown]
# ## **MAKING DataFrame for LOOKUP condition : data_halte_count**

# %% [markdown]
# Now we will be filling the NA from the tapInStops column. First we make the LOOKUP table were we find every combination of stops Name and ID from our tj DataFrame

# %%
data_halte_count = pd.pivot_table(data = tj,
               index = ['tapInStops','tapInStopsName'],
               values = 'tapInStopsLat',
               aggfunc= 'count').sort_values(by=['tapInStops']).reset_index().rename(columns={'tapInStopsLat': 'used'}).sort_values('used', ascending = False)

data_halte_count
# Out:
#      tapInStops            tapInStopsName  used
# 2462     P00170               Penjaringan   236
# 2370     P00064         Garuda Taman Mini   200
# 2328     P00016                       BKN   170
# 2568     P00297                   BNN LRT   151
# 2457     P00164                   Pejaten   145
# ...         ...                       ...   ...
# 26      B00059P  Apotik Emilia Rawamangun     1
# 24      B00056P   Apartemen Kedoya Elok 2     1
# 23      B00052P                Antena III     1
# 39      B00090P   Azhari Islamic School 1     1
# 101     B00206P              Bulak Rantai     1
#
# [2570 rows x 3 columns]

# %% [markdown]
# Checking for duplicates because the map function will return an error if there is a duplicated values inside the lookup table

# %%
# Check for duplicates in the 'tapInStops' column
data_halte_count[data_halte_count['tapInStops'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [tapInStops, tapInStopsName, used]
# Index: []

# %%
# Check for duplicates in the 'tapInStopsName' column
data_halte_count[data_halte_count['tapInStopsName'].duplicated(keep=False)]
# Out:
#      tapInStops tapInStopsName  used
# 2359     P00052   Dukuh Atas 2    20
# 2569     P00298   Dukuh Atas 2     1

# %% [markdown]
# We find the duplicates, This Stops Name should only have 1 ID, and since the one above have been used more, I'll take it as the correct one.

# %%
tj[tj['tapInStops'] == 'P00298']
# Out:
#               transID     payCardID payCardBank       payCardName payCardSex  \
# 33176  RVXV189M7J06ND  501834837947       flazz  Cahyanto Maulana          M
#
#        payCardBirthDate corridorID                  corridorName  direction  \
# 33176              1985         M4  Pulo Gadung 2 - Dukuh Atas 2        1.0
#
#       tapInStops tapInStopsName  tapInStopsLat  tapInStopsLon  stopStartSeq  \
# 33176     P00298   Dukuh Atas 2      -6.204494     106.823327             0
#
#                  tapInTime tapOutStops tapOutStopsName  tapOutStopsLat  \
# 33176  2023-04-15 06:55:23      P00152   Pasar Genjing       -6.194446
#
#        tapOutStopsLon  stopEndSeq           tapOutTime  payAmount
# 33176       106.86092         4.0  2023-04-15 07:53:38     3500.0

# %% [markdown]
# ## **FILLING tapInStopsName with MAP**

# %%
# Deleting the duplicate, it will automatically drop the second occurance and since our LOOKUP is sorted we'll drop the one that is used only once
data_halte_count = data_halte_count.drop_duplicates(subset='tapInStopsName')

# Map the 'source' column in tj to the 'apply_to' column in data_stasiun_count and fill missing values
tj['tapInStops'] = tj['tapInStops'].fillna(
    tj['tapInStopsName'].map(data_halte_count.set_index('tapInStopsName')['tapInStops'])
)

# %%
transjakarta.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops            34
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %% [markdown]
# We successfully fill almost all of the tapInStops, these remaining NA means we don't find a match with our LOOKUP table and we have to either manually fill them, or drop them. Since there is only 34 data out of 37 thousand data, the significance of these 34 data is so low that it is not worth filling the NA manually.

# %% [markdown]
# ## **FILLING tapOutStops with MAP**

# %% [markdown]
# We will be using the same process as the one above, The same LOOKUP table only this time we're using the Stops OUT instead of IN. Then we will use this LOOKUP table to fill the TapOutStopsName

# %%
data_halte_count2 = pd.pivot_table(data = tj,
               index = ['tapOutStops','tapOutStopsName'],
               values = 'tapOutStopsLat',
               aggfunc= 'count').sort_values(by=['tapOutStops']).reset_index().rename(columns={'tapOutStopsLat': 'used'}).sort_values('used', ascending = False)

data_halte_count2.drop_duplicates(subset='tapOutStopsName', inplace = True)

# %%
tj['tapOutStops'] = tj['tapOutStops'].fillna(
    tj['tapOutStopsName'].map(data_halte_count2.set_index('tapOutStopsName')['tapOutStops']))

# %%
transjakarta.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops            34
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         1363
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %% [markdown]
# It occurs to me that the still missing stops ID is because our LOOKUP table doesn't represent all the stops population, only the stops sample from our data which is not complete. So there might be a difference in the tapIn and tapOut stops and we can try Mapping them to each outher LOOKUP table

# %%
tj['tapInStops'] = tj['tapInStops'].fillna(
    tj['tapInStopsName'].map(data_halte_count2.set_index('tapOutStopsName')['tapOutStops'])
)

# %%
tj['tapOutStops'] = tj['tapOutStops'].fillna(
    tj['tapOutStopsName'].map(data_halte_count.set_index('tapInStopsName')['tapInStops']))

# %%
transjakarta.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops            22
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         1353
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %% [markdown]
# ## **MAKING DataFrame for LOOKUP condition : data_customer_stasiun**

# %% [markdown]
# Because there's only 2000 unique customer inside our data, i suspect that there might be a lot of repeat usage of stations, meaning the same customer tapOut in the same location every time they tapIn from a certain location. this LOOKUP pivot table will be used to prove that conjecture

# %%
data_customer_stasiun = pd.pivot_table(data = tj,
               index = ['payCardID','tapInStops', 'tapOutStops'],
               values = 'tapInStopsLat',
               aggfunc= 'count').sort_values(by=['tapInStopsLat'], ascending = False).reset_index().rename(columns={'tapInStopsLat': 'used'})

data_customer_stasiun
# Out:
#                 payCardID tapInStops tapOutStops  used
# 0     4997693930906134609    B02234P     B03795P    20
# 1     4963710913075879668    B03885P     B06067P    20
# 2     4957958811110735429    B04678P     B05764P    20
# 3     4941966320527194737     P00237      P00074    20
# 4     4916430456848946627    B06803P     B05728P    20
# ...                   ...        ...         ...   ...
# 4942         501830527583     P00033      P00002     1
# 4943         501830527583     P00129      P00079     1
# 4944         501834837947    B00248P      P00016     1
# 4945         501834837947    B00866P     B04005P     1
# 4946       30207713127087     P00046      P00239     1
#
# [4947 rows x 4 columns]

# %%
data_customer_stasiun.groupby('used')[['payCardID']].count()
# Out:
#       payCardID
# used
# 1          2946
# 2             1
# 5             9
# 6            67
# 7           324
# 15            1
# 16           10
# 17           38
# 18          193
# 19          593
# 20          765

# %% [markdown]
# The conjecture turns out correct, there's a lot of reccuring users of the transjakarta inside our data with the same tapIn and tapOut combination, this means we could predict and fillNA on tapOut based on where the certain customer tapIN

# %% [markdown]
# ## **FILLING tapOutStops with MAP and Composite_key to fullfill 2 conditions**

# %% [markdown]
# Now filling the NA coulnd't be done with just one condition on the MAP, from our previous conjecture, the same customer with the a certain TapIn location would tapOut in the same location as the usually do. this means the MAP that we're using currently have to fullfill 2 conditions of the same customer and the same tapIn instead of only 1 like how it's previously done. To do this we could make a composite key of those 2 conditions where we combine those condition into one inside a single collumns called composite key and then MAP the data with that composite key.

# %%
# Making the composite Key
tj['composite_key'] = tj['payCardID'].astype(str) + '_' + tj['tapInStops'].astype(str)
data_customer_stasiun['composite_key'] = data_customer_stasiun['payCardID'].astype(str) + '_' + data_customer_stasiun['tapInStops'].astype(str)

# Deleting Duplicate
data_customer_stasiun.drop_duplicates(subset= 'composite_key', inplace = True)

tj['tapOutStops'] = tj['tapOutStops'].fillna(
    tj['composite_key'].map(data_customer_stasiun.set_index('composite_key')['tapOutStops'])
)

# %%
tj.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops            22
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops          131
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# composite_key          0
# dtype: int64

# %% [markdown]
# ## **MAKING DataFrame for LOOKUP condition : tapOutDetails**

# %% [markdown]
# We will now be filling all of the missing collumns of the tapOutStops with a single LOOKUP table

# %%
tapOutDetails = pd.pivot_table(data = tj,
               index = ['tapOutStops','tapOutStopsName','tapOutStopsLat','tapOutStopsLon','stopEndSeq'],
               values = 'transID',
               aggfunc= 'count').sort_values(by=['transID']).reset_index().rename(columns={'transID': 'used'}).sort_values('used', ascending = False)

tapOutDetails.drop_duplicates(subset='tapOutStops', inplace = True)

# %%
# Fill the Stops name
tj['tapOutStopsName'] = tj['tapOutStopsName'].fillna(
    tj['tapOutStops'].map(tapOutDetails.set_index('tapOutStops')['tapOutStopsName']))

# %%
# Fill the Stops Latitude
tj['tapOutStopsLat'] = tj['tapOutStopsLat'].fillna(
    tj['tapOutStops'].map(tapOutDetails.set_index('tapOutStops')['tapOutStopsLat']))

# %%
# Fill the Stops Longitude
tj['tapOutStopsLon'] = tj['tapOutStopsLon'].fillna(
    tj['tapOutStops'].map(tapOutDetails.set_index('tapOutStops')['tapOutStopsLon']))

# %%
# Fill the Stops Sequence
tj['stopEndSeq'] = tj['stopEndSeq'].fillna(
    tj['tapOutStops'].map(tapOutDetails.set_index('tapOutStops')['stopEndSeq']))

# %%
tj.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1125
# corridorName        1125
# direction              0
# tapInStops            22
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops          131
# tapOutStopsName      122
# tapOutStopsLat       122
# tapOutStopsLon       122
# stopEndSeq           122
# tapOutTime          1344
# payAmount           1007
# composite_key          0
# dtype: int64

# %% [markdown]
# ## **MAKING DataFrame for LOOKUP condition : corridor_name_sequence**

# %% [markdown]
# Since there is still a lot of corridor ID and Name that is NA, we have to find a new way to fill it. What we can do is we make a LOOKUP table for corridorID with every single avaliable stopsName with their directions and sequence. We have to use direction and sequence because the same Stops or Halte is used by multiple Route, so we have to match a every Stops with the routes directions and sequence. The same Stops will have a different sequence and direction for their routes.

# %%
# Making the pivot table
corridor_name_sequence = pd.pivot_table(
    tj,
    index = ['corridorID', 'corridorName', 'direction', 'tapInStops', 'tapInStopsName'],
    values = 'stopStartSeq',
    aggfunc = 'median'
).sort_values(by=['corridorID','direction', 'stopStartSeq']).reset_index()
corridor_name_sequence
# Out:
#      corridorID                   corridorName  direction tapInStops  \
# 0             1                  Blok M - Kota        0.0     P00017
# 1             1                  Blok M - Kota        0.0     P00133
# 2             1                  Blok M - Kota        0.0     P00012
# 3             1                  Blok M - Kota        0.0     P00256
# 4             1                  Blok M - Kota        0.0     P00137
# ...         ...                            ...        ...        ...
# 3805        T21  Palem Semi - Bundaran Senayan        1.0    B00322P
# 3806        T21  Palem Semi - Bundaran Senayan        1.0    B06909P
# 3807        T21  Palem Semi - Bundaran Senayan        1.0    B05770P
# 3808        T21  Palem Semi - Bundaran Senayan        1.0    B00808P
# 3809        T21  Palem Semi - Bundaran Senayan        1.0    B02861P
#
#           tapInStopsName  stopStartSeq
# 0                 Blok M           0.0
# 1           Masjid Agung           2.0
# 2        Bendungan Hilir           6.0
# 3             MH Thamrin          11.0
# 4                  Monas          13.0
# ...                  ...           ...
# 3805           DPR MPR 2           6.0
# 3806  Slipi Petamburan 3           7.0
# 3807     Tol Kb. Jeruk 1           8.0
# 3808             Islamic          10.0
# 3809        Plaza Europa          11.0
#
# [3810 rows x 6 columns]

# %% [markdown]
# Because as we found previously that the tapIn and tapOut have contains different unique Stops name, we have to include both for out LOOKUP table

# %%
corridor_name_sequence2 = pd.pivot_table(
    tj,
    index = ['corridorID', 'corridorName', 'direction', 'tapOutStops', 'tapOutStopsName'],
    values = 'stopEndSeq',
    aggfunc = 'median'
).sort_values(by=['corridorID','direction', 'stopEndSeq']).reset_index()
corridor_name_sequence2
# Out:
#      corridorID                   corridorName  direction tapOutStops  \
# 0             1                  Blok M - Kota        0.0      P00183
# 1             1                  Blok M - Kota        0.0      P00010
# 2             1                  Blok M - Kota        0.0      P00137
# 3             1                  Blok M - Kota        0.0      P00295
# 4             1                  Blok M - Kota        0.0      P00139
# ...         ...                            ...        ...         ...
# 3299        T21  Palem Semi - Bundaran Senayan        1.0     B00808P
# 3300        T21  Palem Semi - Bundaran Senayan        1.0     B02861P
# 3301        T21  Palem Semi - Bundaran Senayan        1.0     B02557P
# 3302        T21  Palem Semi - Bundaran Senayan        1.0     B01440P
# 3303        T21  Palem Semi - Bundaran Senayan        1.0     B02556P
#
#                 tapOutStopsName  stopEndSeq
# 0              Polda Metro Jaya         5.0
# 1     Bank Indonesia Arah Utara        12.0
# 2                         Monas        13.0
# 3       Mangga Besar Arah Utara        16.0
# 4                         Olimo        17.0
# ...                         ...         ...
# 3299                    Islamic        10.0
# 3300               Plaza Europa        11.0
# 3301               Palem Semi 2        12.0
# 3302     Jln. Palem Jepang Baru        13.0
# 3303               Palem Semi 1        14.0
#
# [3304 rows x 6 columns]

# %% [markdown]
# Turns out using LOOKUP table for this process would take a long time and compute, the easier way is to use a dictionary inside a dictionary, the outer dictionary will use the Route or coriddorID and direction as the key, the value is another dictionary with their sequence as key, and the Stops name as values.

# %%
# making the corridorID + direction
corridor_name_sequence.insert(2, 'concated_key', corridor_name_sequence['corridorID'].astype(str) + '_' + corridor_name_sequence['direction'].astype(str))

# %%
# making the corridorID + direction
corridor_name_sequence2.insert(2, 'concated_key', corridor_name_sequence2['corridorID'].astype(str) + '_' + corridor_name_sequence2['direction'].astype(str))

# %% [markdown]
# Turning each LOOKUP table into a dictionary

# %%
grouped_directions_in = corridor_name_sequence.groupby('concated_key').apply(
    lambda x: x[['stopStartSeq', 'tapInStopsName']].values.tolist()
)

# Convert to dictionary
grouped_directions_in_dict = grouped_directions_in.to_dict()

# %%
grouped_directions_out = corridor_name_sequence2.groupby('concated_key').apply(
    lambda x: x[['stopEndSeq', 'tapOutStopsName']].values.tolist()
)

# Convert to dictionary
grouped_directions_out_dict = grouped_directions_out.to_dict()

# %% [markdown]
# Combining the 2 dictionary into a single Dictionary

# %%
# Initialize an empty dictionary for the result
combined_dict = {}

# Merge the dictionaries
for key in set(grouped_directions_in_dict) | set(grouped_directions_out_dict):  # Union of all keys in both dictionaries
    combined_values = {}
    if key in grouped_directions_in_dict:
        combined_values.update({item[0]: item[1] for item in grouped_directions_in_dict[key]})  # Convert each list to tuple and add to set
    if key in grouped_directions_out_dict:
        combined_values.update({item[0]: item[1] for item in grouped_directions_out_dict[key]})  # Convert each list to tuple and add to set
    
    # Convert back to list of lists and sort if necessary
    combined_dict[key] = combined_values

combined_dict
# Out:
# {'3C_1.0': {0.0: 'Penjaringan', 1.0: 'Rusun Kapuk Muara'},
#  '10H_1.0': {0.0: 'Blok M',
#   3.0: 'Bundaran Senayan',
#   5.0: 'Slipi Petamburan Arah Utara',
#   6.0: 'Slipi Kemanggisan Arah Utara',
#   10.0: 'Petojo',
#   11.0: 'Pecenongan',
#   13.0: 'Pasar Baru',
#   14.0: 'Pasar Baru Timur',
#   8.0: 'Tomang Mandala',
#   15.0: 'Jembatan Merah',
#   16.0: 'Gunung Sahari Mangga Dua',
#   17.0: 'Pademangan',
#   18.0: 'Tanjung Priok'},
#  'JAK.60_1.0': {0.0: 'Kemayoran Landas Pacu Timur 2',
#   4.0: 'Jln. H. Mawar Sunter',
#   6.0: 'Jln. Sunter Jaya VI',
#   16.0: 'Wisma SMR',
#   18.0: 'SPBU Yos Sudarso',
#   19.0: 'Sunter Kelapa Gading 1',
#   23.0: 'Ruko Gading Kirana',
#   25.0: 'Ruko Gading Kirana 3',
#   29.0: 'Sbr. Jakarta Taipei School',
#   34.0: 'Jln. Kelapa Hybrida IV',
#   37.0: 'Pusat Pelayanan Warga Summarecon',
#   38.0: 'Singapore International School',
#   24.0: 'Ruko Gading Kirana 2',
#   28.0: 'Mitra Gading Villa',
#   30.0: 'Sbr. BPK Penabur Kelapa Gading',
#   33.0: 'Jln. Kelapa Hybrida 10',
#   35.0: 'Jln. Gading Ayu I',
#   43.0: 'RS Gading Pluit',
#   45.0: 'Simpang Kepu Arteri Kelapa Gading'},
#  'JAK.14_0.0': {1.0: 'Jak Lingko Tanah Abang 2',
#   3.0: 'Jln. Taman Jatibaru Timur',
#   4.0: 'Pharmin',
#   9.0: 'Bongkaran Tanah Abang',
#   12.0: 'Gg. Petamburan I KS Tubun',
#   19.0: 'Slipi Petamburan 1',
#   22.0: 'Ps. Palmerah 2',
#   29.0: 'Simpang Palmerah Barat Rawa Belong',
#   32.0: 'Perumahan Perwira Mabad',
#   34.0: 'Sbr. Jln. KH Syahdan',
#   35.0: 'Sekolah Tarsisius 2',
#   49.0: 'Kec. Kb. Jeruk',
#   51.0: 'Pos Pengampuan',
#   53.0: 'Simpang Meruya Ilir Srengseng',
#   17.0: 'Sbr. Sekolah Lamuel',
#   21.0: 'Sbr. SDN Palmerah 07',
#   43.0: 'YPI Al Huda Kb. Jeruk',
#   44.0: 'SMAN 65',
#   55.0: 'SPBU Meruya Ilir',
#   57.0: 'Ruko Meruya Ilir',
#   58.0: 'Ruko Taman Kb. Jeruk',
#   63.0: 'Simpang Permata Meruya 1',
#   64.0: 'Jln. Permata Meruya'},
#  '2F_0.0': {2.0: 'Tipar Cakung',
#   3.0: 'Cakung United Tractors',
#   4.0: 'SMK Nurul Huda',
#   5.0: 'Rusun Tipar Cakung',
#   6.0: 'Rusun Cakung Barat Albo'},
#  '1E_0.0': {4.0: 'Jln. H. Muslim',
#   6.0: 'Dapsus 2',
#   8.0: 'Jln. Banjarsari II',
#   9.0: 'Ps. Mede',
#   10.0: 'SMKN 28',
#   12.0: 'St. Cipete Raya 2',
#   13.0: 'Golden Fatmawati',
#   15.0: 'H. Nawi Jln. Madrasah',
#   16.0: 'Sbr. ITC Fatmawati',
#   19.0: 'Jln. Sungai Sambas VI',
#   14.0: 'Jln. Mangga',
#   20.0: 'Plaza Blok M',
#   23.0: 'Blok M Jalur 3'},
#  'D21_1.0': {3.0: 'RA Kartini',
#   9.0: 'Ratu Prabu',
#   11.0: 'Cilandak',
#   12.0: 'Ampera 1',
#   18.0: 'Jln. Nangka 1',
#   20.0: 'ACC Simatupang',
#   23.0: 'St. Tj. Barat 1',
#   24.0: 'Tj. Mas Raya',
#   26.0: 'Poltek Bunda Kandung',
#   28.0: 'SPBU Jln. Guru',
#   30.0: 'Taman Lenteng Agung',
#   31.0: 'St. Lenteng Agung 1',
#   33.0: 'SMAN 38',
#   35.0: 'Syibi',
#   17.0: 'Jln. H. Saidi',
#   19.0: 'Jln. Muara 1',
#   32.0: 'Wijaya Kusuma',
#   36.0: 'Univ. Indonesia'},
#  '7D_0.0': {0.0: 'Pancoran Tugu Arah Barat',
#   1.0: 'TIS Square',
#   2.0: 'Jembatan Pintu Satu',
#   3.0: 'Sbr. Masjid At Tin',
#   5.0: 'BNN LRT',
#   8.0: 'BNN Arah Barat',
#   10.0: 'Masjid At Tin',
#   11.0: 'Sbr. Jembatan Pintu Satu',
#   16.0: 'Nizamia Andalusia',
#   6.0: 'Pondok Gede Raya',
#   12.0: 'Tebet Eco Park II Arah Barat',
#   13.0: 'Pancoran Tugu Arah Barat',
#   17.0: 'Jln. Bambu Hubuny',
#   18.0: 'Gerbang Tol Bambu Apus 2',
#   19.0: 'Jln. Gempol Raya',
#   20.0: 'Gempol',
#   23.0: 'Jln. Nangka'},
#  'T21_0.0': {5.0: 'Perpustakaan Riset BPK',
#   6.0: 'Senayan JCC 3',
#   9.0: 'Gelora Bung Karno 1',
#   11.0: 'Bundaran Senayan 1',
#   10.0: 'Summitmas',
#   12.0: 'Bundaran Senayan 2'},
#  'JAK.14_1.0': {0.0: 'Ps. Jabon Meruya',
#   1.0: 'Kantor PJU',
#   3.0: 'Simpang Permata Meruya 2',
#   7.0: 'Kec. Kembangan',
#   11.0: 'Olieku Jln. Aries Permai',
#   15.0: 'Sbr. Perum Qoriyah Toyibah',
#   49.0: 'Sbr. Masjid Annur Tanah Abang',
#   52.0: 'JPO Blok G',
#   18.0: 'Jln. Jeruk Manis',
#   19.0: 'Jln. Sitrun',
#   20.0: 'Simpang Panjang Kb. Jeruk 2',
#   33.0: 'Jln. Palmerah Barat IV',
#   34.0: 'SDN Palmerah 09',
#   51.0: 'Museum Textile',
#   53.0: 'Jak Lingko Tanah Abang'},
#  '3C_0.0': {0.0: 'Rusun Kapuk Muara', 1.0: 'Penjaringan'},
#  '1C_0.0': {1.0: 'Univ. Moestopo Bintaro',
#   5.0: 'Bintaro Park VIew',
#   19.0: 'Sbr. Sangrila Indah',
#   25.0: 'Seskoal 2',
#   28.0: 'Kebayoran Baru Velbak 2',
#   30.0: 'Puskesmas Kel. Gunung',
#   31.0: 'Mayestik 2',
#   34.0: 'CSW 2',
#   12.0: 'Sbr. SMPN 235',
#   32.0: 'RS Pusat Pertamina 2',
#   35.0: 'Blok M Jalur 2'},
#  'B13_0.0': {0.0: 'Summarecon Bekasi',
#   1.0: 'RS Mitra Keluarga 1',
#   2.0: 'Kayuringin 1',
#   4.0: 'Bekasi Barat',
#   5.0: 'Komdak 1',
#   9.0: 'Bundaran Senayan 1',
#   10.0: 'St. MRT Asean 1',
#   11.0: 'Kejaksaan Agung',
#   3.0: 'Mega Mall Bekasi',
#   8.0: 'Summitmas',
#   12.0: 'Blok M Jalur 4'},
#  'JAK.80_1.0': {3.0: 'Pabrik Plastik Sawah Mede',
#   7.0: 'Sbr. Jln. H. Minan Kamal',
#   14.0: 'Simpang Benda Raya Prepedan',
#   15.0: 'Sbr. SMPN 190',
#   22.0: 'Jln. Menceng Raya',
#   25.0: 'Jln. Menceng Raya 1',
#   27.0: 'Jln. Prima',
#   41.0: 'SMA Cengkareng 1',
#   42.0: 'Panti Sosial Bina Laras 1',
#   12.0: 'Sbr. TPU Tegal Alur',
#   18.0: 'Sbr. Masjid Al Ichrom',
#   34.0: 'Sbr. SMAN 95',
#   38.0: 'Yayasan Miftahussaadah',
#   39.0: 'Masjid Safinatul Husna',
#   45.0: 'Ps. Pisang Rawa Buaya'},
#  '12H_0.0': {0.0: 'Rusun Penjaringan', 1.0: 'Penjaringan'},
#  '1H_0.0': {0.0: 'St. Gondangdia 2',
#   1.0: 'Selatan St. Gondangdia',
#   2.0: 'Masjid Cut Nyak Dien',
#   3.0: 'Khong Guan Wahid Hasyim',
#   4.0: 'Sbr. The Pakubuwono Menteng',
#   5.0: 'MH Thamrin 3',
#   6.0: 'Sbr. Jln. Kampung Bali XXXIII',
#   9.0: 'Simpang Blok A',
#   14.0: 'Blok F',
#   16.0: 'JPO Blok G',
#   8.0: 'Jln. Kb. Kacang VIII',
#   10.0: 'Tanah Abang AURI',
#   11.0: 'Blok E',
#   12.0: 'Pharmin',
#   13.0: 'Explorer Tanah Abang',
#   17.0: 'Jak Lingko Tanah Abang 2'},
#  'JAK.22_0.0': {0.0: 'Lapangan Bola Danu Setiawan',
#   1.0: 'Jln. Pontian Halim',
#   3.0: 'Jln. Sambu Halim',
#   6.0: 'Ps. Mini Halim',
#   10.0: 'Masjid Hidayatussalam',
#   11.0: 'Mess Wirayudha 2',
#   12.0: 'Pos Jaga Trikora 2',
#   13.0: 'Lion Center',
#   9.0: 'SMA Angkasa 1',
#   14.0: 'Halim PK',
#   15.0: 'Cawang Soetoyo 2',
#   16.0: 'Cawang Soetoyo 1'},
#  'JAK.19_1.0': {2.0: 'Gg. Ali',
#   4.0: 'Jln. Mastrip',
#   9.0: 'Setu 2',
#   14.0: 'Simpang Rukun 2',
#   18.0: 'Sbr. Gg. Waru',
#   25.0: 'Jln. Alhidayah III',
#   27.0: 'Gg. Service',
#   30.0: 'TK Dinamika',
#   33.0: 'SMAN 113',
#   35.0: 'Gg. Sadar Vb',
#   39.0: 'Pertigaan Al-Baidho',
#   40.0: 'Masjid Jami Al-Baidlo',
#   46.0: 'Sbr. Jln. Swadaya II',
#   47.0: 'Gg. H Piran',
#   53.0: 'SPBU Pinang Ranti 2',
#   37.0: 'SDN Lubang Buaya 11',
#   41.0: 'Asshomadiyah Medicare Centre 2',
#   43.0: 'Jln. Tpa II',
#   44.0: 'Pertigaan Manunggal Al-Baidho',
#   45.0: 'Jln. Sepakat',
#   48.0: 'Pintu II TMII',
#   51.0: 'Sbr. Jln. Mundu',
#   52.0: 'Jln. H Mahid',
#   54.0: 'Term. Pinang Ranti'},
#  '9_1.0': {8.0: 'RS Harapan Kita Arah Selatan',
#   11.0: 'Senayan JCC Arah Timur',
#   12.0: 'Semanggi',
#   17.0: 'Pancoran Tugu Arah Timur',
#   21.0: 'BNN LRT',
#   24.0: 'Garuda Taman Mini',
#   14.0: 'Kuningan Barat',
#   19.0: 'Cikoko Stasiun Cawang Arah Timur',
#   23.0: 'Cawang UKI',
#   25.0: 'Pinang Ranti'},
#  'JAK.07_0.0': {0.0: 'Jak Lingko Tanah Abang',
#   3.0: 'Jln. Taman Jatibaru Timur',
#   5.0: 'Explorer Tanah Abang',
#   9.0: 'Bongkaran Tanah Abang',
#   11.0: 'Hotel Kalisma KS Tubun',
#   17.0: 'Wisma 77',
#   19.0: 'Wisma Asia II',
#   20.0: 'Jln. Tali Kota Bambu Selatan',
#   23.0: 'Jln. Kota Bambu Raya',
#   26.0: 'Taman Juang 2',
#   42.0: 'Ps. Timbul',
#   16.0: 'Jln. Petamburan IIb',
#   22.0: 'Jln. Kota Bambu Selatan IV',
#   24.0: 'Simpang Kota Bambu Utara I',
#   25.0: 'Simpang Semangka II',
#   32.0: 'Simpang Seroja Cempaka',
#   35.0: 'Kel. Jati Pulo',
#   36.0: 'Pospol Tomang 2',
#   37.0: 'Simpang Mandala Selatan Raya',
#   43.0: 'Sbr. Masjid Jami Al Hidayah Tomang',
#   46.0: 'Simpang Tawakal Kyai Tapa'},
#  'B13_1.0': {0.0: 'Blok M Jalur 4',
#   1.0: 'Bundaran Senayan 2',
#   6.0: 'Mall Metropolitan',
#   7.0: 'Kayuringin 2',
#   8.0: 'RS Mitra Keluarga 2',
#   9.0: 'Bandar Djakarta Bekasi',
#   5.0: 'Komdak 2',
#   10.0: 'Summarecon Bekasi'},
#  'S11_0.0': {0.0: 'Term. BSD',
#   12.0: 'RS Asshobirin 1',
#   13.0: 'SDN Pondok Jagung 1',
#   20.0: 'Gading Serpong 1',
#   21.0: 'Warung Mangga 1',
#   24.0: 'Tol Kb. Jeruk 2',
#   10.0: 'WTC Matahari 1',
#   14.0: 'Batalyon Kavaleri 1',
#   19.0: 'Pratama Abadi',
#   22.0: 'Kb. Nanas',
#   26.0: 'Jelambar'},
#  'JAK.22_1.0': {2.0: 'Ps. Ciplak',
#   3.0: 'Pos Jaga Trikora 1',
#   4.0: 'Mess Wirayudha 1',
#   6.0: 'Sbr. SMA Angkasa 1',
#   9.0: 'Mabes Au Dinas Psikologi',
#   10.0: 'Simpang Mandala Maphalindo',
#   11.0: 'Sbr. Jln. Sambu Halim',
#   7.0: 'SD Angkasa 7',
#   8.0: 'Sbr. Mess Perwira Cendrawasih',
#   13.0: 'Jln. Pura Agung Taman Sari',
#   14.0: 'Lapangan Bola Danu Setiawan'},
#  'JAK.50_1.0': {8.0: 'Simpang Kembangan Utara Bojong Raya',
#   11.0: 'Jln. Madrasah I Bojong Raya',
#   12.0: 'Masjid Jami Al Ittihadiyah',
#   13.0: 'Sbr. Jln. H. Kincan Rawa Buaya',
#   22.0: 'Masjid Jami Nurul Fauz',
#   29.0: 'Jln. H. Komeng Duri Kosambi',
#   30.0: 'Jln. Al Falah Duri Kosambi',
#   36.0: 'Sbr. Green Puri',
#   41.0: 'St. Kalideres',
#   45.0: 'Sbr. SDN Semanan 01',
#   46.0: 'Sekolah Daarun Naiim',
#   47.0: 'Sbr. Ps. Hipli Semanan',
#   18.0: 'Ps. Pisang Rawa Buaya',
#   34.0: 'Sbr. Ruko Green Lake',
#   35.0: 'Daarus Saada Duri Kosambi',
#   38.0: 'Sbr. SMPN 205',
#   39.0: 'Sbr. Gg. H. Anim Semanan',
#   43.0: 'Sbr. Jln. Semanan II',
#   44.0: 'Jln. H. Hamid Semanan',
#   48.0: 'Komplek Polri Kalideres',
#   49.0: 'Kalideres 1'},
#  'JAK.113_1.0': {0.0: 'Gg. Swadaya 2 G',
#   1.0: 'Jembatan Sungai Landak 1',
#   2.0: 'MTsN 5',
#   6.0: 'BPJS Ketenagakerjaan Marunda',
#   7.0: 'EKS Komplek Gaya Motor',
#   10.0: 'Jln. Dewa Ruci',
#   11.0: 'Pure Dalam',
#   12.0: 'Jln. Kramat Jaya',
#   13.0: 'Jln. B Lagoa Terusan 2',
#   14.0: 'Jln. A Lagoa',
#   17.0: 'Masjid Al Mukarromah Jampea',
#   18.0: 'RSUD Koja',
#   15.0: 'Jln. Cilincing Raya 1',
#   16.0: 'Pertamina Kilang Minyak',
#   19.0: 'Jln. Lorong 22',
#   20.0: 'Jln. Lorong 19',
#   21.0: 'Jln. Lorong 5',
#   23.0: 'Permai Koja 2'},
#  '8_0.0': {0.0: 'Lebak Bulus',
#   4.0: 'Tanah Kusir Kodim',
#   8.0: 'Permata Hijau',
#   9.0: 'Permata Hijau RS Medika',
#   17.0: 'Jelambar',
#   18.0: 'Grogol 2 Arah Selatan',
#   19.0: 'S Parman Podomoro City Arah Timur',
#   22.0: 'Petojo',
#   5.0: 'Kebayoran Lama Bungur',
#   16.0: 'Indosiar',
#   21.0: 'RS Tarakan',
#   23.0: 'Pecenongan',
#   24.0: 'Juanda',
#   25.0: 'Pasar Baru'},
#  'JAK.86_1.0': {1.0: 'Manggarai 1',
#   2.0: 'Sbr. RSIA Tambak',
#   3.0: 'Sbr. St. Manggarai',
#   4.0: 'Sbr. Jln. Manggarai Utara 5',
#   8.0: 'Bank BRI Kayu Manis',
#   9.0: 'Gg. Oyot',
#   10.0: 'Jln. Pisangan Baru Utara 1',
#   14.0: 'Universitas Terbuka',
#   16.0: 'Kampus Frans Seda',
#   19.0: 'Kel. Rawamangun',
#   22.0: 'TK Tarakanita 5',
#   25.0: 'Total Buah Rawamangun',
#   5.0: 'Simpang Manggarai Utara',
#   6.0: 'Taman Gg. Kelor',
#   17.0: 'Jln. Rawamangun Selatan 2',
#   21.0: 'Jln. Rawamangun Muka Timur',
#   24.0: 'Puskesmas Rawamangun',
#   26.0: 'Term. Rawamangun'},
#  'JAK.31_0.0': {2.0: 'Jln. Palatehan II',
#   18.0: 'Sbr. Jln. H. Jian 2B Cipete',
#   21.0: 'Jln. Bunga Cempaka II Cipete',
#   23.0: 'Simpang Bunga Melati Flamboyan',
#   30.0: 'SMPN 68',
#   38.0: 'Simpang Cilandak Tengah Raya 1',
#   41.0: 'Simpang Tb Simatupang Tunda Bara',
#   42.0: 'Komplek RSPP',
#   45.0: 'Komplek DDN 1',
#   52.0: 'Simpang DDN Pondok Labu',
#   43.0: 'Jln. Berlian II Pondok Labu',
#   47.0: 'Sbr. Kel. Pondok Labu',
#   49.0: 'Sbr. Jln. Pinang IIIb',
#   53.0: 'Sbr. Akper Fatmawati Pondok Labu',
#   55.0: 'Andara Margasatwa 1',
#   56.0: 'Jln. H. Terin Pangkalan Jati'},
#  '9D_1.0': {0.0: 'Term. Pasar Minggu',
#   1.0: 'Term. Pasar Minggu 2',
#   9.0: 'Pomad 2',
#   13.0: 'RS Tria Dipa',
#   18.0: 'Kuningan Barat',
#   23.0: 'Gatot Subroto LIPI 1',
#   24.0: 'Direktorat Jenderal Pajak',
#   25.0: 'Komdak 1',
#   26.0: 'Semanggi',
#   30.0: 'Karet Sudirman 3',
#   31.0: 'Grand Sahid',
#   32.0: 'Menara Astra',
#   34.0: 'St. Sudirman 2',
#   42.0: 'JPO Blok E',
#   43.0: 'Pharmin',
#   44.0: 'Explorer Tanah Abang',
#   47.0: 'JPO Blok G',
#   16.0: 'PMI',
#   27.0: 'Benhil 2',
#   28.0: 'Benhil 3',
#   35.0: 'Tosari',
#   36.0: 'Bundaran HI',
#   37.0: 'MH Thamrin',
#   38.0: 'Menara Thamrin',
#   41.0: 'Jln. Taman Kb. Sirih',
#   45.0: 'Blok F',
#   46.0: 'Pospol Jati Bunder',
#   48.0: 'Jak Lingko Tanah Abang 2'},
#  '9N_1.0': {0.0: 'BKN', 1.0: 'Garuda Taman Mini', 2.0: 'Pinang Ranti'},
#  'JAK.113_0.0': {0.0: 'Permai Koja 2',
#   4.0: 'Pertamina Term. Priok',
#   5.0: 'Pertamina Marine III',
#   6.0: 'Bogasari',
#   10.0: 'Sbr. Jln. Jaya Wijaya',
#   11.0: 'Jln. Cilincing Baru Raya',
#   13.0: 'GKJ Tj. Priok',
#   16.0: 'Kec. Cilincing',
#   17.0: 'Puskesmas Cilincing',
#   18.0: 'Taman Jln. Bhakti 1',
#   9.0: 'Tanah Merdeka 2',
#   14.0: 'Sbr. Ps. Pagi Raya Cilincing',
#   15.0: 'Simpang Raya Cilincing Sungai Landak',
#   19.0: 'Gg. Swadaya 2 G'},
#  'JAK.49_0.0': {5.0: 'Jln. Panjang',
#   9.0: 'Gg. H. Sanusi I Ulujami',
#   10.0: 'Simpang Jln. H. Baserin 2',
#   23.0: 'Sbr. Kodam Bintaro',
#   24.0: 'Jln. Gambas Kodam Bintaro',
#   25.0: 'Jln. Cempedak Pesanggrahan',
#   26.0: 'SD Kartika X-4',
#   28.0: 'RSUD Pesanggrahan',
#   29.0: 'SDN Pesanggrahan 10 Pagi',
#   42.0: 'Kel. Pondok Pinang',
#   46.0: 'Sbr. Raffles Christian School',
#   47.0: 'Jln. Metro Duta 1',
#   48.0: 'JPO Timur Pondok Indah 1',
#   20.0: 'Sbr. Jln. Beo',
#   34.0: 'Kolong Tol Jakarta Serpong 2',
#   35.0: 'Kolong Tol Guru Saleh',
#   39.0: 'Exit Tol Veteran Bintaro',
#   43.0: 'Imigrasi Kelas I Jaksel',
#   44.0: 'Masjid Jami Al Falah Pinang',
#   49.0: 'St. MRT Lebak Bulus',
#   50.0: 'Lebak Bulus Jak Lingko',
#   51.0: 'Jln. Lebak Bulus Raya'},
#  'JAK.61_0.0': {1.0: 'Cempaka Timur 2',
#   16.0: 'RS Mitra Kelapa Gading',
#   19.0: 'Ruko Gading Bukit Indah',
#   24.0: 'Ruko Gading Kirana',
#   29.0: 'Gereja Tiberias Kelapa Gading',
#   30.0: 'Sherwood',
#   38.0: 'Boulevard Kelapa Cengkir Raya',
#   41.0: 'Simpang Jln. Tarian Raya Barat',
#   20.0: 'Raya Gading Bukit Indah',
#   25.0: 'Ruko Gading Kirana 2',
#   26.0: 'Ruko Gading Kirana 3',
#   32.0: 'Jln. Kelapa Nias IV',
#   39.0: 'Simpang Kelapa Cengkir Raya',
#   40.0: 'Simpang Kelapa Cengkir Flamboyan',
#   42.0: 'Simpang Kepu Arteri Kelapa Gading',
#   44.0: 'Sbr. Puskesmas Pegangsaan Dua'},
#  '2F_1.0': {0.0: 'Rusun Cakung Barat Albo',
#   1.0: 'Rusun Tipar Cakung',
#   3.0: 'Cakung United Tractors',
#   5.0: 'Jln. Radjiman 2',
#   8.0: 'Jln. Anggrek Raya',
#   9.0: 'Gg. H Sayuti I',
#   11.0: 'Sbr. Jln. Anggrek Raya',
#   13.0: 'Pulo Jaya',
#   15.0: 'PTC Pulo Gadung',
#   2.0: 'Sbr. SMK Nurul Huda',
#   7.0: 'Pangarengan',
#   10.0: 'Sbr. Gg. H. Sayuti I',
#   12.0: 'Rajiman 2',
#   16.0: 'Pulo Gadung'},
#  'JAK.86_0.0': {0.0: 'Term. Rawamangun',
#   2.0: 'Perguruan Advent VII Rawamangun',
#   4.0: 'Tip Top Rawamangun',
#   6.0: 'Jln. Cipinang Timur Persahabatan',
#   7.0: 'Klinik Hemodialisa Pandaoni Medika',
#   12.0: 'Jln. Bujana Tirta Raya 2',
#   24.0: 'Sbr. RPTRA Pesona Manggarai',
#   13.0: 'Ahmad Yani Bea Cukai 1',
#   15.0: 'Flyover Jatinegara 1',
#   16.0: 'Flyover Jatinegara Atas',
#   17.0: 'Ahmad Yani Pisangan Baru',
#   22.0: 'Sbr. Taman Gg. Kelor',
#   25.0: 'St. Manggarai'},
#  'M4_1.0': {0.0: 'Dukuh Atas 2',
#   4.0: 'Pasar Genjing',
#   7.5: 'Layur',
#   9.0: 'Sunan Giri',
#   10.0: 'Velodrome',
#   14.0: 'Pasar Pulo Gadung',
#   5.0: 'Velodrome',
#   11.0: 'Pemuda Rawamangun',
#   13.0: 'TU Gas',
#   15.0: 'Pulo Gadung 2'},
#  '11K_1.0': {0.0: 'Penggilingan', 1.0: 'Rusun Komarudin'},
#  'JAK.15_0.0': {2.0: 'Rusun Marunda 1',
#   9.0: 'KBN Marunda 2',
#   16.0: 'SMPN 143',
#   22.0: 'Simpang Kebantenan VIII',
#   23.0: 'Sbr. Gg. Oxport Kebantenan',
#   30.0: 'Jln. Belimbing Terusan',
#   35.0: 'Jln. Komplek Cakrawala',
#   36.0: 'SDN Lagoa',
#   40.0: 'Simpang Lagoa Ciampea',
#   41.0: 'Pertamina Kilang Minyak',
#   47.0: 'Jln. Lorong 4',
#   17.0: 'Sbr. Ps. Jongkok',
#   26.0: 'Sbr. Kel. Semper Timur',
#   39.0: 'Ps. Sinar Lagoa 1',
#   42.0: 'Masjid Al Mukarromah Jampea',
#   44.0: 'Jln. Lorong 22',
#   49.0: 'Port Medical Center',
#   50.0: 'Jln. Elpa Putih II',
#   52.0: 'Term. Tj. Priok 1'},
#  '12P_1.0': {2.0: 'Sbr. SDN Sunter Agung 09',
#   3.0: 'RS Dr. Sulianti Saroso',
#   4.0: 'Jln. Sunter Permai 1',
#   6.0: 'Sunter Karya',
#   8.0: 'Sunter Kelapa Gading Arah Utara',
#   11.0: 'Villa Bukit Gading',
#   12.0: 'St. LRT Boulevard Utara 2',
#   13.0: 'Puskesmas Kelapa Gading',
#   9.0: 'MOI Kelapa Gading',
#   14.0: 'Kel. Pegangsaan Dua'},
#  'JAK.12_1.0': {0.0: 'St. Kebayoran 2',
#   4.0: 'Sbr. TPU Grogol Selatan',
#   6.0: 'Komplek Hankam Cidodol',
#   31.0: 'Jln. Asshofa Raya',
#   33.0: 'Jln. Madrasah II Sukabumi Selatan',
#   46.0: 'RS Bhakti Mulia',
#   52.0: 'Sbr. Masjid Annur Tanah Abang',
#   55.0: 'JPO Blok G',
#   13.0: 'Jln. Pahlawan Sukabumi Selatan',
#   29.0: 'Jln. WW Sukabumi Selatan',
#   34.0: 'Jln. Adam Sukabumi Utara',
#   42.0: 'Sbr. Ps. Palmerah',
#   51.0: 'Jln. KS Tubun II',
#   56.0: 'Jak Lingko Tanah Abang'},
#  'B14_0.0': {2.0: 'Kayuringin 1',
#   3.0: 'Mega Mall Bekasi',
#   7.0: 'Kemenkes 1',
#   8.0: 'Kemenkes 2',
#   9.0: 'BNI Syariah',
#   11.0: 'GOR Sumantri 2',
#   13.0: 'Kuningan Madya 2',
#   14.0: 'Menara Duta',
#   5.0: 'Kuningan Timur 2',
#   10.0: 'Kedubes Malaysia',
#   12.0: 'Karet Kuningan 2',
#   15.0: 'Setiabudi Utara 2'},
#  '4F_0.0': {2.0: 'RS Haji Jakarta',
#   3.0: 'Sbr. Ps. Gardu',
#   18.0: 'UNKRIS',
#   20.0: 'Gerbang Tol Pondok Gede',
#   25.0: 'Simpang Kalimalang',
#   39.0: 'Sbr. Ps. Klender',
#   44.0: 'Pool Mayasari Bakti',
#   46.0: 'SD Jatinegara Kaum',
#   8.0: 'Griya Kukila Halim Perdanakusuma',
#   24.0: 'Pospol Makasar',
#   35.0: 'Sbr. Balai Rakyat',
#   47.0: 'Masjid Assuada',
#   49.0: 'Pintu Kawasan 2'},
#  'M1H_0.0': {1.0: 'Selatan St. Gondangdia',
#   3.0: 'Khong Guan Wahid Hasyim',
#   4.0: 'Sbr. The Pakubuwono Menteng',
#   6.0: 'Sbr. Jln. Kampung Bali XXXIII',
#   8.0: 'Jln. Kb. Kacang VIII',
#   11.0: 'Blok E',
#   13.0: 'Explorer Tanah Abang',
#   14.0: 'Blok F',
#   16.0: 'JPO Blok G',
#   17.0: 'Jak Lingko Tanah Abang',
#   5.0: 'MH Thamrin 3',
#   7.0: 'Jln. Kb. Kacang X',
#   12.0: 'Pharmin',
#   15.0: 'Pospol Jati Bunder',
#   18.0: 'Jak Lingko Tanah Abang 2'},
#  'JIS3_1.0': {0.0: 'Harmoni Arah Utara',
#   2.0: 'Mangga Besar Arah Utara',
#   3.0: 'Mangga Besar Arah Selatan',
#   6.0: 'Pecenongan',
#   7.0: 'Juanda',
#   8.0: 'Pasar Baru Timur',
#   9.0: 'Kemayoran Landas Pacu Timur',
#   11.0: 'Simpang Danau Sunter Utara Barat',
#   12.0: 'Sunter Icon',
#   4.0: 'Sawah Besar Arah Selatan',
#   10.0: 'Danau Agung',
#   13.0: 'Jembatan Item',
#   14.0: 'JIS'},
#  'JAK.120_1.0': {0.0: 'Term. Muara Angke 2',
#   2.0: 'Baywalk 1',
#   3.0: 'Baywalk 2',
#   6.0: 'Stella Maris 1',
#   8.0: 'SMKN 56',
#   9.0: 'Pluit Sakti',
#   10.0: 'Simpang Pakin 3',
#   14.0: 'Simpang Kopi Roa Malaka',
#   16.0: 'Gg. Kunir II',
#   17.0: 'Kota 1',
#   23.0: 'Gg. Souw Beng Kong',
#   24.0: 'Jln. Pangeran Jayakarta',
#   25.0: 'Jln. Industri III',
#   27.0: 'Jln. Industri I',
#   37.0: 'BNN Jakarta Utara',
#   38.0: 'Jln. Sunter Permai 2',
#   39.0: 'Sbr. RS Dr. Sulianti Saroso',
#   41.0: 'Sbr. Taman BMW',
#   12.0: 'Gedong Panjang 2',
#   13.0: 'BRI Jakarta Kota',
#   20.0: 'Pangeran Jayakarta 1',
#   21.0: 'Jln. Mangga Dua I Selatan',
#   28.0: 'Perlintasan KA Rajawali',
#   30.0: 'Jln. Mokmer 1',
#   32.0: 'Aula Simfonia',
#   33.0: 'Flyover HBR Motik 1',
#   34.0: 'Flyover HBR Motik 2',
#   35.0: 'The Mansion Bougenvile',
#   40.0: 'SDN Sunter Agung 09',
#   42.0: 'Taman BMW'},
#  '12A_1.0': {1.0: 'Kali Besar Barat',
#   2.0: 'Bandengan Selatan',
#   3.0: 'Penjaringan',
#   6.0: 'Stella Maris 2',
#   7.0: 'SD Diakonia 2',
#   9.0: 'PLTU',
#   13.0: 'Muara Karang Raya',
#   15.0: 'SMAK Penabur Enam 2',
#   10.0: 'Pluit 1',
#   11.0: 'SPBG Jakpro',
#   16.0: 'Term. Muara Angke 2',
#   17.0: 'Perumahan Buddha Tzu Chi 2',
#   18.0: 'Pelabuhan Kali Adem'},
#  'JAK.53_0.0': {10.0: 'Hotel Mega Anggrek',
#   21.0: 'Simpang Anggrek Garuda Rosaliana',
#   24.0: 'Sbr. Komplek Kijang Kencana',
#   32.0: 'Icon Residence',
#   47.0: 'Gg. Mawar Kb. Jeruk',
#   54.0: 'Jln. Srengseng Dalam Lap Bola',
#   58.0: 'Jln. Pemancingan Srengseng',
#   31.0: 'Sbr. Binus Syahdan',
#   37.0: 'Jln. Harun II Sukabumi Utara',
#   61.0: 'Jln. Srengseng Raya 3',
#   62.0: 'Sbr. SMAN 85',
#   65.0: 'Jln. Karya Utama',
#   67.0: 'Perum Villa Kelapa Dua',
#   70.0: 'Jln. Inspeksi Kali Pesanggrahan Barat'},
#  '2P_0.0': {1.0: 'Masjid Cut Meutia 1',
#   2.0: 'BRI Menteng',
#   3.0: 'Kanisius',
#   5.0: 'Gambir 3',
#   6.0: 'Tugu Tani 1',
#   7.0: 'Panti Perwira',
#   9.0: 'Atrium 2',
#   10.0: 'RSPAD 1',
#   11.0: 'RSPAD 3',
#   8.0: 'Atrium 1',
#   12.0: 'Wahidin 1',
#   14.0: 'Term. Senen'},
#  'JAK.58_1.0': {5.0: 'SDN Rorotan 07',
#   6.0: 'Mushola Almujtahida Rorotan',
#   11.0: 'SMKN 4',
#   14.0: 'Malaka 1 Gg. 2 Rorotan',
#   18.0: 'Gg. Bulak I Rorotan',
#   23.0: 'Komplek KPLP Marunda',
#   27.0: 'Sbr. Marunda Baru',
#   31.0: 'Gg. H. Abdul Rohim Marunda',
#   32.0: 'Sbr. Masjid Nurul Jannah Marunda',
#   45.0: 'Sbr. Cilincing Baru Raya',
#   46.0: 'Jln. Nanggala Dewa Kembar',
#   47.0: 'Jln. Pasopati Dewa Kembar',
#   51.0: 'Masjid Jami Al Fallah',
#   52.0: 'RSUD Cilincing',
#   62.0: 'Ramayana Semper',
#   19.0: 'Ponpes Alhikmah Rorotan',
#   24.0: 'SMKN Jasalena Marunda',
#   29.0: 'Sbr. MIN 20 Jakarta',
#   35.0: 'Ps. Bebek Marunda 2',
#   36.0: 'KBN Marunda 2',
#   41.0: 'Simpang Sungai Landak Raya Cilincing',
#   50.0: 'Sbr. SMP Nurul Falah',
#   56.0: 'Jln. Pemadam Kebakaran Cacing',
#   57.0: 'PLN Pusat Raya Tugu',
#   58.0: 'Gereja Katholik Salib Suci',
#   64.0: 'Koja Trade Mall'},
#  '11M_0.0': {2.0: 'Penggilingan',
#   3.0: 'Perumnas Klender',
#   4.0: 'Flyover Radin Inten',
#   5.0: 'Buaran',
#   6.0: 'Kampung Sumur',
#   13.0: 'St. Jatinegara 2',
#   15.0: 'Masjid As Sudairi',
#   7.0: 'Flyover Klender',
#   10.0: 'Imigrasi Jakarta Timur',
#   16.0: 'Masjid Attahiriyah'},
#  '10D_1.0': {0.0: 'Kampung Rambutan',
#   4.0: 'Pasar Induk Kramat Jati',
#   8.0: 'Pulo Mas Bypass',
#   9.0: 'Cempaka Putih',
#   10.0: 'Cempaka Mas',
#   15.0: 'Permai Koja Arah Utara',
#   7.0: 'Kayu Putih Rawasari',
#   11.0: 'Yos Sudarso Kodamar',
#   12.0: 'Sunter Kelapa Gading Arah Utara',
#   13.0: 'Plumpang Pertamina Arah Utara',
#   17.0: 'Tanjung Priok'},
#  '5N_0.0': {2.0: 'Flyover Kampung Melayu',
#   3.0: 'Kampung Melayu Besar 2',
#   10.0: 'Transvision Jln. Tebet Raya',
#   16.0: 'GPIB Bukit Moria',
#   25.0: 'SMPN 124',
#   26.0: 'Simpang Kemang Utara Timur',
#   38.0: 'Ampera 1',
#   39.0: 'RSUD Pasar Minggu',
#   40.0: 'Univ. Tarumanegara Cilandak KKO',
#   49.0: 'Gg. Borobudur Ragunan',
#   50.0: 'Gg. Tamansari Ragunan',
#   31.0: 'Gojek Kemang Timur',
#   36.0: 'RSIA Kemang',
#   43.0: 'Jln. Kampung Utan Cilandak KKO',
#   45.0: 'Sbr. SMK Al Hidayah 1',
#   51.0: 'Ragunan 2',
#   52.0: 'Term. Ragunan'},
#  '7A_1.0': {1.0: 'Selapa Polri',
#   4.0: 'Gelanggang TB Simatupang',
#   8.0: 'Cilandak Tengah',
#   11.0: 'Cilandak',
#   12.0: 'Ampera 1',
#   13.0: 'Jatipadang Raya',
#   14.0: 'Jln. Jatipadang Poncol',
#   15.0: 'Jln. Mujair Raya',
#   18.0: 'Jln. Nangka 1',
#   20.0: 'Plaza Pp Condet 2',
#   24.0: 'Jln. Baru Tanah Merdeka',
#   25.0: 'Jln. Mastrip',
#   17.0: 'Jln. H. Saidi',
#   21.0: 'RSUD Pasar Rebo 2',
#   23.0: 'RS Jantung Binawaluya',
#   27.0: 'Term. Kampung Rambutan'},
#  'JAK.40_1.0': {4.0: 'Yayasan Nurul Ihsan Pulo Gebang',
#   19.0: 'Jln. Satria',
#   20.0: 'Kota Harapan Indah 1',
#   21.0: 'Sbr. Sentral Bisnis Harapan Indah',
#   32.0: 'Sbr. Griya Harapan Permai',
#   36.0: 'Masjid Jami Al Muhsinin',
#   37.0: 'Jln. Irigasi THB',
#   38.0: 'THB Cluster Nirwana',
#   29.0: 'SMAN 10 Bekasi',
#   39.0: 'Jln. Kavling PGRI',
#   41.0: 'Jln. Permata Indah 8',
#   45.0: 'Simpang Bundaran Ikan Harapan Indah Raya 1',
#   46.0: 'Jln. Bougenvil Indah',
#   47.0: 'Ruko Taman Cemara'},
#  'JAK.115_0.0': {0.0: 'Term. Tj. Priok 1',
#   2.0: 'Sbr. Port Medical Center',
#   6.0: 'Sbr. Gg. I Jln. Cipeucang V',
#   9.0: 'Jln. Mengkudu Dalam',
#   17.0: 'RS Pelabuhan Jakarta',
#   18.0: 'Sbr. Jln. Komplek Yuka',
#   21.0: 'Jln. Batu Tumbuh I',
#   31.0: 'Jln. Kelapa Nias IV',
#   33.0: 'Masjid Raya Al Musyawarah Kelapa Gading 2',
#   37.0: 'Jln. Pegangsaan Dua 7',
#   38.0: 'Sbr. Jln. H. Oyar',
#   16.0: 'Wisma Islamic Centre',
#   19.0: 'Sbr. Ramayana Semper',
#   22.0: 'SPBU Tugu Selatan',
#   23.0: 'Jln. Rawa Indah 1',
#   28.0: 'Gading Nirwana',
#   35.0: 'RS Gading Pluit',
#   39.0: 'Jln. Pegangsaan Dua 9',
#   40.0: 'Simpang Jln. Pegangsaan Dua'},
#  '6N_1.0': {0.0: 'Blok M Jalur 2',
#   2.0: 'Yayasan Al Kholidin',
#   7.0: 'Plaza Adorama',
#   11.0: 'Sbr. Jln. Kemang Selatan VIII',
#   12.0: 'Sbr. Plaza Kemang 88',
#   13.0: 'Sbr. Villa Ampera',
#   14.0: 'Simpang Kemang Selatan 2',
#   18.0: 'RSIA Kemang',
#   20.0: 'Ampera 1',
#   21.0: 'Kementerian Pertanian',
#   3.0: 'Kantor Walikota Jaksel',
#   15.0: 'Arsip Nasional RI 2',
#   16.0: 'Pengadilan Negeri Jaksel 2',
#   17.0: 'Komplek Polri Ragunan',
#   19.0: 'Ampera 4',
#   22.0: 'PLN Corporate University 2'},
#  '9E_0.0': {3.0: 'Gedung Pertamina',
#   4.0: 'Limo',
#   5.0: 'Permata Hijau 1',
#   6.0: 'Juraganan',
#   7.0: 'Saadatudarain',
#   9.0: 'Sbr. Hotel Mulia',
#   10.0: 'Kompas Gramedia',
#   11.0: 'Ps. Palmerah',
#   14.0: 'S Parman Podomoro City Arah Barat',
#   15.0: 'Jelambar'},
#  'R1A_0.0': {0.0: 'Pantai Maju',
#   3.0: 'Seberang Food Street',
#   5.0: 'Fresh Market PIK',
#   12.0: 'Mandara Permai 5',
#   16.0: 'Karang Asri 2',
#   17.0: 'SMAK Penabur Enam 1',
#   32.0: 'Simpang Pakin 3',
#   33.0: 'SPBU Gedong Panjang',
#   34.0: 'Gedong Panjang 2',
#   38.0: 'Gg. Kunir II',
#   6.0: 'PIK Avenue',
#   23.0: 'SD Diakonia 1',
#   28.0: 'Aston Pluit 1',
#   29.0: 'Polsek Penjaringan',
#   30.0: 'SDN Penjaringan 3',
#   37.0: 'Jembatan Kota Intan',
#   39.0: 'Simpang Kunir Kemukus',
#   40.0: 'Kota 1'},
#  '6B_1.0': {0.0: 'MH Thamrin',
#   1.0: 'Bundaran HI',
#   2.0: 'Tosari',
#   3.0: 'Dukuh Atas',
#   9.0: 'Warung Jati',
#   10.0: 'Buncit Indah',
#   12.0: 'Jati Padang',
#   13.0: 'SMK 57',
#   14.0: 'Departemen Pertanian',
#   6.0: 'Mampang Prapatan',
#   11.0: 'Pejaten',
#   15.0: 'Ragunan'},
#  'JAK.05_1.0': {3.0: 'Kb. Baru',
#   4.0: 'Sbr. Pos Ayam',
#   6.0: 'Sbr. TPU Budi Darma',
#   8.0: 'Sbr. Koko Semesta',
#   15.0: 'Sbr. Jln. Cilincing Bakti',
#   17.0: 'Pusdiklatnas 1',
#   23.0: 'Masjid Nurul Jannah Marunda',
#   26.0: 'Jln. Marunda Baru',
#   21.0: 'Ps. Bebek Marunda 1',
#   24.0: 'Gg. P Pertamina Marunda',
#   31.0: 'Gg. Barokah Marunda',
#   32.0: 'Jln. Kaliabang Rorotan',
#   34.0: 'MI Arruhaniyah Rorotan',
#   36.0: 'Rorotan BKT'},
#  'S12_1.0': {0.0: 'St. MRT Fatmawati',
#   2.0: 'Carrefour Lebak Bulus',
#   3.0: 'Sbr. Versailles',
#   1.0: 'RS Siloam',
#   4.0: 'Term. BSD'},
#  'JAK.11_1.0': {0.0: 'St. Kebayoran 2',
#   1.0: 'Jln. Jiban I Grogol Selatan',
#   11.0: 'RS Medika Permata Hijau 3',
#   16.0: 'Jln. Asshofa Raya',
#   18.0: 'Jln. Madrasah II Sukabumi Selatan',
#   20.0: 'Simpang Rawa Belong Palmerah Barat',
#   21.0: 'Jln. Palmerah Barat IV',
#   25.0: 'Sbr. Ps. Pisang',
#   26.0: 'Sbr. The Jakarta Post',
#   31.0: 'RS Bhakti Mulia',
#   33.0: 'Sbr. Sekolah Bethel',
#   36.0: 'Jln. KS Tubun II',
#   37.0: 'Sbr. Masjid Annur Tanah Abang',
#   38.0: 'Gedung ATC',
#   10.0: 'H Soleh I Sukabumi Selatan',
#   15.0: 'Jln. EE Sukabumi Selatan',
#   19.0: 'Jln. Adam Sukabumi Utara',
#   28.0: 'SDN Palmerah 07',
#   29.0: 'Jln. Palmerah Utara II',
#   32.0: 'Sekolah Lemuel',
#   39.0: 'Museum Textile',
#   40.0: 'JPO Blok G'},
#  'JAK.73_0.0': {0.0: 'PKP',
#   3.0: 'Sbr. Jln. Melati PKP',
#   5.0: 'Sbr. Taman Mahoni',
#   10.0: 'Polsek Pasar Rebo',
#   12.0: 'Simpang Belly 1',
#   13.0: 'Simpang Belly 2',
#   14.0: 'Jln. Buah Cijantung',
#   15.0: 'Gongseng',
#   19.0: 'Sekolah Islam PB Soedirman',
#   21.0: 'Simpang Anyelir',
#   23.0: 'Sbr. RS Harapan Bunda',
#   24.0: 'Jakarta Islamic Hospital'},
#  'JAK.43C_1.0': {0.0: 'Jln. Tebet Timur Dalam VIII J',
#   1.0: 'Tebet Eco Park Selatan 3',
#   2.0: 'Tebet Eco Park Selatan 2',
#   3.0: 'Tebet Eco Park Utara',
#   5.0: 'Jln. Tebet Barat Raya',
#   4.0: 'Rusun Harum Tebet',
#   6.0: 'Jln.Tebet Barat V'},
#  '1_1.0': {4.0: 'Olimo',
#   5.0: 'Mangga Besar Arah Selatan',
#   8.0: 'Monas',
#   10.0: 'MH Thamrin',
#   12.0: 'Tosari',
#   13.0: 'Dukuh Atas',
#   14.0: 'Karet Sudirman',
#   15.0: 'Bendungan Hilir',
#   20.0: 'Kejaksaan Agung',
#   16.0: 'Polda Metro Jaya',
#   17.0: 'Gelora Bung Karno',
#   18.0: 'Bundaran Senayan',
#   19.0: 'Masjid Agung',
#   21.0: 'Blok M'},
#  '10A_1.0': {0.0: 'Tanjung Priok',
#   2.0: 'Madya Kebantenan',
#   3.0: 'Bidara 2',
#   4.0: 'STIP',
#   5.0: 'Rumah Sipitung',
#   6.0: 'Rusun Marunda 2',
#   7.0: 'Rusun Marunda'},
#  'JAK.08_1.0': {3.0: 'RS Dr Mintohardjo',
#   6.0: 'Sbr. Mess Polwan Esthi Bhakti Warapsari',
#   8.0: 'Pam Jaya DKI',
#   10.0: 'Rusun Benhil',
#   12.0: 'Sbr. TPU Karet Bivak',
#   13.0: 'Kec. Tanah Abang',
#   15.0: 'Kesatrian Kowal Cut Nyak Dhien',
#   21.0: 'JPO Blok G',
#   25.0: 'Jln. Taman Jatibaru Timur',
#   17.0: 'Kel. Kb. Kacang',
#   23.0: 'Jak Lingko Tanah Abang 2',
#   28.0: 'Sbr. Taman Tulang Bawang',
#   30.0: 'Gedung Pompa Cideng Siantar',
#   33.0: 'ITC Roxy'},
#  'JAK.74_0.0': {0.0: 'Jln. Gotong Royong Cipinang Muara',
#   2.0: 'Sbr. Jln. H. Hanafi Cipinang',
#   5.0: 'Sbr. MTsN 25 Jakarta',
#   8.0: 'Rsu Pengayoman',
#   10.0: 'Sekolah Bahasa Polri',
#   11.0: 'Nabawi Islamic School',
#   13.0: 'Persahabatan',
#   19.0: 'SMKN 7',
#   1.0: 'Masjid Jami At Taqwa 3',
#   9.0: 'Logistik Polri',
#   12.0: 'Sudin Pencatatan Sipil 1',
#   15.0: 'HKBP Rawamangun',
#   17.0: 'Rukan Balai Pustaka',
#   20.0: 'Term. Rawamangun'},
#  '2H_0.0': {1.0: 'SDN Johar Baru 10',
#   3.0: 'Bengkel Jln. Letjen Suprapto',
#   4.0: 'Honda Letjen Suprapto',
#   5.0: 'RSPAD 1'},
#  'JAK.53_1.0': {12.0: 'Jln. H. Nasir Srengseng',
#   24.0: 'Jln. Musyawarah Panjang Arteri',
#   29.0: 'Jln. Salam IV',
#   41.0: 'Sbr. Airy Eco Binus',
#   54.0: 'Sbr. Jln. Bhakti VII Palmerah',
#   57.0: 'Pusdiklat Pajak Jln. Sakti IV',
#   59.0: 'Jln. Bima Kemanggisan',
#   62.0: 'Univ. Tarumanegara 2',
#   19.0: 'Sbr. Ps. Pengampuan',
#   25.0: 'Sbr. Jln. Madrasah Sukabumi Utara',
#   63.0: 'Term. Grogol 2'},
#  '5C_0.0': {1.0: 'BKN',
#   4.0: 'BNN LRT',
#   5.0: 'Cawang Otista',
#   8.0: 'Matraman Baru',
#   10.0: 'Tegalan',
#   11.0: 'Matraman 1',
#   17.0: 'Balai Kota',
#   18.0: 'Monas',
#   2.0: 'Cawang UKI',
#   9.0: 'Slamet Riyadi',
#   12.0: 'Salemba Carolus',
#   14.0: 'Kramat Sentiong',
#   15.0: 'Pal Putih',
#   16.0: 'Kwitang',
#   19.0: 'Pecenongan',
#   20.0: 'Juanda'},
#  'JAK.77_1.0': {0.0: 'Term. Tj. Priok 1',
#   10.0: 'Jln. Warakas I Gg. 8',
#   12.0: 'Puskesmas Kel. Warakas',
#   20.0: 'Metro Sunter',
#   25.0: 'Sbr. Gelanggang Remaja Tj. Priok',
#   26.0: 'Sbr. TK Kreatif Komimo',
#   32.0: 'Taman Sunter',
#   33.0: 'RS Mitra Kemayoran',
#   38.0: 'Sbr. Jln. Ancol Selatan',
#   39.0: 'Sbr. Sunter Agung',
#   41.0: 'Jembatan Item',
#   6.0: 'Simpang Ps. Warakas 3',
#   28.0: 'Danau Agung 13',
#   40.0: 'Sbr. Ps. Bambu Kuning',
#   42.0: 'Sbr. Taman BMW',
#   43.0: 'Taman BMW'},
#  '6N_0.0': {0.0: 'Ragunan',
#   2.0: 'Bumi Perkemahan Ragunan',
#   4.0: 'Ampera 3',
#   5.0: 'Sekolah Sumbangsih',
#   6.0: 'Ampera Garden',
#   10.0: 'Arsip Nasional RI 1',
#   13.0: 'Jln. Villa Ampera',
#   16.0: 'Kemang Raya 40',
#   21.0: 'Jln. Kemang 1',
#   22.0: 'Jln. Taman Kemang',
#   23.0: 'Simpang Dharmawangsa VIII',
#   25.0: 'Kejaksaan Agung',
#   7.0: 'Jln. Kenanga',
#   8.0: 'STPDN',
#   12.0: 'Simpang Kemang Selatan 1',
#   14.0: 'Plaza Kemang 88',
#   17.0: 'LPPI 1',
#   19.0: 'Simpang Kemang 1',
#   24.0: 'Puskesmas Kebayoran Baru',
#   26.0: 'Blok M Jalur 2'},
#  'JAK.120_0.0': {7.0: 'Jln. Angkasa Bundaran Kemayoran',
#   10.0: 'Pusat Pengelolaan Komplek Kemayoran',
#   12.0: 'SPBU Industri Kemayoran',
#   20.0: 'Roda Mas Baja Intan',
#   22.0: 'Sbr. Jln. Mangga Dua Dalam',
#   30.0: 'Jln. Bandengan Utara 1',
#   34.0: 'Sbr. Waduk Pluit',
#   37.0: 'PLTU Pluit',
#   38.0: 'Sbr. Baywalk 2',
#   23.0: 'St. Jayakarta 2',
#   26.0: 'Sbr. Sekolah Fajar Sion',
#   29.0: 'Simpang Kopi Bandengan Selatan',
#   32.0: 'Tanah Pasir Gedong Panjang',
#   36.0: 'SD Diakonia 2',
#   40.0: 'Term. Muara Angke 2'},
#  '7P_0.0': {1.0: 'Sbr. SMPN 252',
#   2.0: 'SDN Pondok Kelapa 05',
#   3.0: 'Komplek Ddn Bintara Jaya',
#   4.0: 'Sbr. Jln. Swakarsa III',
#   6.0: 'PPKD Jaktim',
#   8.0: 'Kapin',
#   9.0: 'Embun Pagi Islamic Elementary School',
#   27.0: 'Lion Center',
#   15.0: 'Sbr. Polsek Duren Sawit',
#   18.0: 'Pangkalan Jati 2',
#   23.0: 'Jln. Cipinang Tengah',
#   31.0: 'Transjakarta Pintu 1'},
#  '5M_0.0': {7.0: 'Slamet Riyadi 1',
#   12.0: 'Masjid Jami Matraman',
#   13.0: 'Tugu Proklamasi',
#   17.0: 'Teuku Cik Ditiro',
#   18.0: 'RS Mata Menteng',
#   20.0: 'Konsil Kedokteran Indonesia',
#   26.0: 'Perpustakaan Nasional',
#   29.0: 'JPO Blok E',
#   16.0: 'SMPN 8',
#   19.0: 'RSIA Bunda 2',
#   22.0: 'Farmasi RP Soeroso',
#   23.0: 'Kanisius',
#   30.0: 'Pharmin',
#   31.0: 'Blok F',
#   32.0: 'Pospol Jati Bunder',
#   33.0: 'JPO Blok G'},
#  'S22_0.0': {0.0: 'Pool PPD Ciputat',
#   1.0: 'SMK Darussalam',
#   3.0: 'Pusdiklat Kemenag 1',
#   4.0: 'Polsek Ciputat 1',
#   5.0: 'Jln. Pesanggrahan',
#   10.0: 'UMJ 1',
#   18.0: 'Tanah Merdeka Arah Timur',
#   20.0: 'Sbr. Term. Kampung Rambutan',
#   6.0: 'Kampus Uin 1',
#   7.0: 'Jln. Wr Supratman',
#   13.0: 'Pondok Pinang',
#   14.0: 'RA Kartini',
#   16.0: 'Jln. Ar Ridho',
#   21.0: 'Kampung Rambutan'},
#  '1A_0.0': {0.0: 'Pantai Maju',
#   2.0: 'Melody Golf 2',
#   3.0: 'Seberang Food Street',
#   6.0: 'PIK Avenue',
#   11.0: 'Mediterania Boulevard',
#   16.0: 'SD Diakonia 1',
#   19.0: 'Landmark Pluit Auto Plaza',
#   21.0: 'Gedong Panjang',
#   24.0: 'Glodok',
#   10.0: 'Mandara Permai 6',
#   15.0: 'Baywalk 2',
#   18.0: 'Pluit Sakti',
#   20.0: 'Pakin',
#   23.0: 'Kota',
#   27.0: 'Sawah Besar Arah Selatan',
#   28.0: 'Harmoni Arah Selatan',
#   29.0: 'Monas'},
#  '13_0.0': {0.0: 'CBD Ciledug',
#   1.0: 'Puri Beta 1',
#   2.0: 'Adam Malik',
#   3.0: 'JORR',
#   4.0: 'Swadarma',
#   6.0: 'Seskoal',
#   7.0: 'Kebayoran Lama',
#   9.0: 'Mayestik',
#   10.0: 'CSW 1',
#   11.0: 'Tirtayasa',
#   12.0: 'Rawa Barat',
#   13.0: 'Tendean'},
#  '9D_0.0': {2.0: 'Jln. Taman Jatibaru Timur',
#   3.0: 'Tanah Abang 2',
#   10.0: 'Chase Plaza',
#   11.0: 'Karet Sudirman 1',
#   16.0: 'Otorita Asahan',
#   17.0: 'Menara Mulia',
#   21.0: 'Jamsostek Gatot Subroto',
#   22.0: 'Balai Kartini',
#   24.0: 'Tegal Parang 2',
#   25.0: 'RS Medistra',
#   30.0: 'Perdatam',
#   43.0: 'Poltangan 1',
#   45.0: 'Grand Pasar Minggu',
#   6.0: 'MH Thamrin',
#   31.0: 'Jln. Pancoran Indah 1',
#   32.0: 'Jln. Bina Harapan',
#   35.0: 'Pom Ad 1',
#   36.0: 'Nifarro Park',
#   39.0: 'YBK',
#   41.0: 'Masjid At Taqwa 1',
#   44.0: 'Mja Rawa Bambu',
#   47.0: 'Pasar Minggu',
#   48.0: 'Term. Pasar Minggu'},
#  'JAK.24_0.0': {6.0: 'Pulo Mas Ruko',
#   11.0: 'Jln. Kelapa Puyuh I',
#   13.0: 'Jln. Summagung II Barat',
#   34.0: 'Simpang Danau Indah Raya',
#   36.0: 'Sbr. Perum Sunter Hijau',
#   39.0: 'Sbr. Jln. Sunter Jaya VI',
#   44.0: 'Sbr. SMPN 10',
#   48.0: 'Simpang Gunung Sahari III',
#   22.0: 'Jln. Mandiri Tengah',
#   33.0: 'Jln. Danau Indah Timur',
#   37.0: 'Sbr. Jln. H. Tamin S',
#   42.0: 'Sbr. SMAN 5',
#   45.0: 'Ps. Sumur Batu 2',
#   46.0: 'SMP Muhammadiyah 2',
#   50.0: 'Term. Senen'},
#  '6C_1.0': {0.0: 'Sbr. Standard Chartered',
#   3.0: 'Ambassador',
#   9.0: 'Telkom Tebet',
#   10.0: 'Sawo Kecik Raya',
#   4.0: 'Kuningan 18',
#   5.0: 'UPT. LLHD 2',
#   6.0: 'Puri Casablanca',
#   7.0: 'Kota Kasablanka',
#   11.0: 'Stasiun Tebet'},
#  '10_1.0': {0.0: 'PGC 2',
#   2.0: 'Cawang UKI',
#   5.0: 'Cipinang Kebon Nanas',
#   7.0: 'Stasiun Jatinegara Arah Utara',
#   8.0: 'Ahmad Yani Bea Cukai',
#   9.0: 'Utan Kayu Rawamangun',
#   11.0: 'Kayu Putih Rawasari',
#   18.0: 'Walikota Jakarta Utara Arah Utara',
#   20.0: 'Enggano',
#   4.0: 'Penas Kalimalang',
#   13.0: 'Cempaka Putih',
#   15.0: 'Yos Sudarso Kodamar',
#   16.0: 'Sunter Kelapa Gading Arah Utara',
#   19.0: 'Permai Koja Arah Utara',
#   21.0: 'Tanjung Priok'},
#  'JAK.44_0.0': {0.0: 'Jln. H. Terin Pangkalan Jati',
#   3.0: 'Andara Margasatwa 3',
#   11.0: 'Pintu Barat Ragunan 1',
#   18.0: 'Jln. Pepaya Raya',
#   25.0: 'Sbr. Sekolah Islam Al Azhar Jagakarsa',
#   27.0: 'Sbr. Gg. Robaya',
#   28.0: 'Sbr. RS Aulia',
#   33.0: 'Gg. H. Tohir',
#   38.0: 'St. Lenteng Agung 1',
#   40.0: 'Jln. Raya Lenteng Agung',
#   13.0: 'Kav Polri Blok E Jagakarsa',
#   24.0: 'SPBU Jagakarsa',
#   26.0: 'Sbr. STIKES Bhakti Pertiwi Jagakarsa',
#   30.0: 'Ibik 57',
#   32.0: 'St. Lenteng Agung 2',
#   34.0: 'Gg. H. Ali',
#   36.0: 'Jln. H. Zakaria',
#   39.0: 'Wijaya Kusuma',
#   41.0: 'Gg. Durian',
#   42.0: 'St. Univ. Pancasila Jak Lingko'},
#  'JAK.48B_1.0': {1.0: 'Bidara Cina 1',
#   2.0: 'STIS',
#   3.0: 'Bidara Cina 2',
#   4.0: 'Klinik Otista',
#   6.0: 'Kampung Melayu Besar 2',
#   5.0: 'Flyover Kampung Melayu',
#   7.0: 'St. Tebet 3'},
#  '11C_0.0': {0.0: 'Rusun Pinus Elok Blok A',
#   2.0: 'Gg. Aim 2',
#   3.0: 'Gg. Sawo 2',
#   4.0: 'Pintu Masuk PIK 2',
#   5.0: 'Simpang Kampung Jembatan 2',
#   7.0: 'Simpang Tiga 2',
#   8.0: 'Walikota Jakarta Timur 1',
#   9.0: 'Rusun Pulo Gebang'},
#  'JAK.23_0.0': {3.0: 'SDN Gunung Sahari 01',
#   5.0: 'Sudin Kebersihan Senen',
#   6.0: 'Jln. Bungur Besar VI',
#   9.0: 'Dittopad 2',
#   14.0: 'Sbr. Gg. Mushola Baburrahman',
#   15.0: 'Jln. Pulo Gundul 1',
#   16.0: 'Jln. Pulo Gundul',
#   19.0: 'Simpang Kramat Jaya Baru 4',
#   24.0: 'SATLAK Johar Baru',
#   25.0: 'Rutan Salemba',
#   27.0: 'Sbr. BPPK Jakarta',
#   28.0: 'Taman Rawasari',
#   33.0: 'Jln. Kemuning Raya 1',
#   34.0: 'Jln. Galur Sari Barat 2',
#   20.0: 'Sbr. Jln. Kramat Jaya Baru I',
#   23.0: 'Jln. Johar Baru 1',
#   32.0: 'Jln. Kemuning 1',
#   35.0: 'Jln. Galur Sari X 2',
#   37.0: 'SDN Utan Kayu Selatan 23 Pagi',
#   38.0: 'Jln. Rasamala',
#   39.0: 'Masjid Asy Syamsu',
#   40.0: 'Jln. Pisangan Baru Tengah 1'},
#  'JAK.20_1.0': {3.0: 'Lakesgilut TNI AU 2',
#   4.0: 'Jln. Bacang Lubang Buaya',
#   5.0: 'Jln. Gorda',
#   14.0: 'Masjid Jami Hasbi',
#   16.0: 'Gg. Ahmad Squadron',
#   18.0: 'Simpang Squadron',
#   22.0: 'Gg. Langga',
#   26.0: 'Jln. Cakrawala',
#   27.0: 'Masjid Al Fida Komodor Halim',
#   31.0: 'Puri Ardhya Garini',
#   33.0: 'BKKBN 2',
#   9.0: 'Sbr. SMPN 128',
#   19.0: 'Taman Intirub 2',
#   28.0: 'TK Angkasa 5',
#   29.0: 'Sbr. Gereja Oikumene',
#   30.0: 'Sbr. Persada Purnawira Halim',
#   32.0: 'Graha Dirgantara',
#   35.0: 'Sekolah Fatimiyah Perdana Kusuma',
#   36.0: 'Cawang Blue Bird 2'},
#  '1H_1.0': {0.0: 'Jak Lingko Tanah Abang 2',
#   4.0: 'SMKN 38',
#   7.0: 'Masjid Ar Rayyan Kementerian BUMN',
#   8.0: 'Dewan Pers',
#   9.0: 'DPRD DKI Jakarta',
#   10.0: 'Sbr. MNC Center',
#   1.0: 'St. Tanah Abang 3',
#   11.0: 'St. Gondangdia 2'},
#  'JAK.37_1.0': {2.0: 'Sbr. Masjid Jami Al Muttaqin Balekambang',
#   4.0: 'Gg. H. Yahya Balekambang',
#   9.0: 'Yayasan Adi Luhur Gedong',
#   11.0: 'Sbr. Graha Delta Tengah',
#   13.0: 'Sbr. SDN Tengah 06',
#   15.0: 'Sbr. Gg. Masjid Al Istiqomah Tengah',
#   16.0: 'Simpang H. Ali Kramat Barat',
#   17.0: 'Jln. Cek Do Abdul Rahman',
#   21.0: 'Sbr. Gg. H. Loong Tengah',
#   35.0: 'Mushola As Salam Batu Ampar',
#   14.0: 'Sbr. Gg. Mundu II Tengah',
#   22.0: 'Jln. Raya Inpres',
#   29.0: 'Jln. Batu Tulis II',
#   38.0: 'Jln. Anggrek Cililitan',
#   40.0: 'Sbr. Masjid Al Hawi Cililitan',
#   41.0: 'PGC Dalam'},
#  '7_1.0': {0.0: 'Bidara Cina',
#   1.0: 'Pasar Jatinegara',
#   2.0: 'Jatinegara RS Premier',
#   6.0: 'BNN LRT',
#   8.0: 'Cawang UKI',
#   10.0: 'PGC 1',
#   12.0: 'Pasar Induk Kramat Jati',
#   13.0: 'RS Harapan Bunda',
#   14.0: 'Flyover Raya Bogor',
#   15.0: 'Tanah Merdeka Arah Timur',
#   3.0: 'Bidara Cina',
#   4.0: 'Gelanggang Remaja',
#   11.0: 'Pasar Kramat Jati',
#   16.0: 'Kampung Rambutan'},
#  'JAK.41_1.0': {0.0: 'Pulo Gadung 4',
#   1.0: 'Gg. Suzuki',
#   10.0: 'Jln. Bawal Raya Paus',
#   16.0: 'Sbr. TK Tarakanita 5',
#   17.0: 'Sbr. SMPN 232',
#   19.0: 'Gg. Gading II Pisangan Timur',
#   23.0: 'Simpang Pori Pisangan Lama III',
#   25.0: 'Simpang Jln. Pisangan Lama',
#   27.0: 'Ps. Enjo Pisangan Lama',
#   28.0: 'SDN Pisangan Timur 05/07',
#   30.0: 'Jln. Bekasi Timur I Jatinegara',
#   32.0: 'Jln. Jatinegara Timur II',
#   22.0: 'Simpang Gading Pori Raya',
#   26.0: 'Simpang Pisangan Lama III Selatan',
#   29.0: 'Flyover Jatinegara 1',
#   31.0: 'Sbr. Ps. Rawa Bening',
#   33.0: 'Jln. Jatinegara Timur III',
#   35.0: 'Jatinegara Timur',
#   36.0: 'Jatinegara RS Primier 1',
#   38.0: 'Jln. Limo Jatinegara Timur',
#   39.0: 'Term. Kampung Melayu 2'},
#  'S22_1.0': {0.0: 'Kampung Rambutan',
#   1.0: 'SMPN 188',
#   4.0: 'Jln. Asmin 2',
#   7.0: 'Flyover Raya Bogor 1',
#   9.0: 'Lebak Bulus',
#   13.0: 'Komplek Mandiri Giant Express 2',
#   20.0: 'Pusdiklat Kemenag 2',
#   21.0: 'Ps. Ciputat',
#   22.0: 'Pom Bensin Ciputat',
#   10.0: 'Cirendeu Permai',
#   11.0: 'Jln. Sandratex 2',
#   18.0: 'Komplek Uin',
#   19.0: 'Polsek Ciputat 2',
#   23.0: 'Pool PPD Ciputat'},
#  'BW9_0.0': {0.0: 'IRTI',
#   2.0: 'St. Gambir 1',
#   4.0: 'Gold Coast',
#   6.0: 'PIK2 Pantjoran',
#   7.0: 'Melody Golf',
#   3.0: 'Buddha Tzu Chi',
#   5.0: 'Food Street',
#   8.0: 'Pantai Maju'},
#  '6A_0.0': {3.0: 'Jati Padang',
#   4.0: 'Pejaten',
#   5.0: 'Buncit Indah',
#   6.0: 'Warung Jati',
#   12.0: 'Departemen Kesehatan',
#   14.0: 'Karet Kuningan',
#   15.0: 'Kuningan Madya',
#   17.0: 'Bundaran HI',
#   7.0: 'Imigrasi',
#   10.0: 'Kuningan Timur',
#   13.0: 'GOR Sumantri',
#   16.0: 'Setiabudi Utara',
#   18.0: 'MH Thamrin'},
#  'JAK.106_0.0': {2.0: 'Institut Teknologi Budi Utomo',
#   7.0: 'Sbr. Jln. Delima Raya 2',
#   8.0: 'Bumi Malaka 2',
#   9.0: 'SMK Bina Darma DKI',
#   10.0: 'Jln. Buaran III',
#   11.0: 'Sbr. Jln. Buaran I',
#   14.0: 'Jln. Dermaga Raya',
#   17.0: 'SKKT Pondok Bambu',
#   19.0: 'Sbr. Masjid Al Iman Cipinang',
#   20.0: 'Jln. Cipinang Jaya Raya',
#   25.0: 'Ps. Enjo 1',
#   28.0: 'Sbr. Ps. Rawa Bening',
#   12.0: 'Jln. Duren Sawit Dermaga',
#   13.0: 'Sbr. Madrasah Hasanatuddarain',
#   15.0: 'Sbr. Komplek Pacul Mas',
#   16.0: 'Koperasi Serba Usaha',
#   23.0: 'Imigrasi Jaktim 1',
#   24.0: 'Jln. Bekasi Timur VI',
#   29.0: 'Jln. Jatinegara Timur II',
#   30.0: 'Jln. Jatinegara Timur III',
#   31.0: 'Jln. Masjid Jatinegara',
#   36.0: 'Term. Kampung Melayu 2'},
#  'JAK.61_1.0': {0.0: 'Pulo Gadung 5',
#   3.0: 'Simpang Kepu Kesadaran',
#   11.0: 'Jln. Pakarena',
#   19.0: 'St. LRT Boulevard Utara 2',
#   30.0: 'Graha Kirana',
#   34.0: 'Simpang Danau Indah Raya',
#   37.0: 'Sbr. Sekolah Saint Caroline',
#   44.0: 'Simpang Bren Howitzer Raya',
#   29.0: 'Boulevard Inspeksi Kali Sunter',
#   41.0: 'Sbr. Ruko Cempaka Mas',
#   43.0: 'Komplek BKN Sumur Batu',
#   45.0: 'Sbr. Kel. Sumur Batu',
#   46.0: 'Ruko Mega Grosir Cempaka Mas'},
#  '6U_0.0': {0.0: 'Blok M Jalur 3',
#   2.0: 'Gunawarman 2',
#   3.0: 'Senopati',
#   7.0: 'Simpang Rawa Barat',
#   8.0: 'Rawa Barat 1',
#   11.0: 'Transvision',
#   13.0: 'Mandiri Griya Mampang',
#   19.0: 'Buncit Indah 2',
#   22.0: 'Koperasi',
#   24.0: 'Kel. Jati Padang',
#   25.0: 'Kec. Pasar Minggu',
#   12.0: 'Tendean 1',
#   15.0: 'Mampang Prapatan',
#   17.0: 'Imigrasi',
#   21.0: 'Jati Padang 2',
#   26.0: 'SMU Balai Rakyat',
#   27.0: 'Sbr. Kel. Ps. Minggu'},
#  'JAK.85_0.0': {6.0: 'RS Islam Pondok Kopi 2',
#   11.0: 'Sbr. Masjid Assaadah Malaka Jaya',
#   12.0: 'Minimarket Pondok Kelapa',
#   26.0: 'Puri Swadaya',
#   28.0: 'Al Khairiyah School',
#   34.0: 'Puskesmas Duren Sawit',
#   35.0: 'Sbr. TDP',
#   18.0: 'Simpang Taman Malaka Utara Barat',
#   33.0: 'Sbr. Masjid Alhikmah Duren Sawit',
#   40.0: 'Univ. Borobudur 4',
#   42.0: 'Mall Cipinang Indah 2',
#   43.0: 'CPI Belakang 2'},
#  'JAK.38_0.0': {1.0: 'Sbr. Mushola Al Muhajirin Cibubur',
#   4.0: 'SMPN 258',
#   6.0: 'Jln. SMAN 99',
#   8.0: 'Simpang Cibubur III/I',
#   9.0: 'SDN Cibubur 11',
#   10.0: 'Taman Mahoni',
#   22.0: 'Sbr. MTsN 7 Model Jakarta',
#   24.0: 'Simpang Bungur Mahakam',
#   11.0: 'Pengadilan Agama 1A Jaktim',
#   17.0: 'Sbr. Jln. Mangga KDW',
#   18.0: 'Jln. Kaja II KDW',
#   23.0: 'Sbr. Kec. Ciracas',
#   26.0: 'Sbr. Jln. Bungur VIII Rambutan',
#   29.0: 'Jln. Bungur Akses Term. 2',
#   30.0: 'Term. Kampung Rambutan'},
#  '1M_0.0': {2.0: 'Pospol Taman Aries',
#   11.0: 'Sbr. Jln. Flamboyan Srengseng',
#   13.0: 'Jln. Lapangan Tenis Srengseng',
#   15.0: 'SMK Satria Srengseng',
#   24.0: 'Jln. H. Rohimin Swadarma',
#   26.0: 'Jln. Swadarma Raya',
#   27.0: 'BSI 2',
#   32.0: 'Jln. Cipulir 1',
#   36.0: 'Puskesmas Kel. Gunung',
#   37.0: 'Mayestik 2',
#   21.0: 'Jln. Kampung Baru V Swadarma',
#   23.0: 'Green Permata',
#   29.0: 'Ps. Sayur Cipulir',
#   30.0: 'Kartini Hospital 2',
#   31.0: 'Seskoal 2',
#   34.0: 'Kebayoran Baru Velbak 2',
#   38.0: 'RS Pusat Pertamina 2',
#   39.0: 'RS Pusat Pertamina 3',
#   40.0: 'CSW 2'},
#  '7C_0.0': {0.0: 'Cibubur Junction', 1.0: 'BKN'},
#  '13D_1.0': {0.0: 'Ragunan',
#   2.0: 'SMK 57',
#   4.0: 'Pejaten',
#   7.0: 'Imigrasi',
#   8.0: 'Duren Tiga',
#   9.0: 'Mampang Prapatan',
#   10.0: 'Tendean',
#   11.0: 'Rawa Barat',
#   14.0: 'Mayestik',
#   15.0: 'Velbak',
#   16.0: 'Kebayoran Lama',
#   3.0: 'Jati Padang',
#   12.0: 'Tirtayasa',
#   17.0: 'Seskoal',
#   21.0: 'Adam Malik',
#   22.0: 'Puri Beta 2'},
#  'JAK.42_0.0': {3.0: 'Sbr. Kel. Rawa Bunga',
#   5.0: 'Taman Simpang Jatinegara',
#   7.0: 'Ps. Enjo 2',
#   11.0: 'Cipinang Lontar',
#   16.0: 'Simpang Mulya Jaya Cipinang Lontar',
#   19.0: 'Sbr. SMPN 148',
#   20.0: 'Sbr. SMAN 50',
#   22.0: 'Sbr. Komplek Pacul Mas',
#   30.0: 'Komplek Abadi 1',
#   31.0: 'Baladewa Residence',
#   33.0: 'Jln. Serdang',
#   34.0: 'Jembatan BKT Pendidikan Raya 1',
#   37.0: 'Sbr. Perum Taman Malaka',
#   39.0: 'Sbr. Jln. Taman Enau',
#   43.0: 'Klapa Village H. Naman',
#   23.0: 'Koperasi Serba Usaha',
#   29.0: 'Komplek Wijaya Kusuma 1',
#   32.0: 'Masjid Jami Al Barkah 1',
#   36.0: 'Univ. Darma Persada 2',
#   38.0: 'Taman Malaka Selatan 2',
#   41.0: 'Jln. Masjid Al Ikhlas',
#   42.0: 'Pospol Pondok Kelapa',
#   44.0: 'Sbr. TPU Pondok Kelapa'},
#  '6B_0.0': {0.0: 'Ragunan',
#   2.0: 'SMK 57',
#   3.0: 'Jati Padang',
#   4.0: 'Pejaten',
#   7.0: 'Imigrasi',
#   12.0: 'Semanggi',
#   14.0: 'Tosari',
#   10.0: 'Gatot Subroto Jamsostek Arah Barat',
#   11.0: 'Gatot Subroto LIPI Arah Barat',
#   13.0: 'Dukuh Atas',
#   15.0: 'Bundaran HI',
#   16.0: 'MH Thamrin'},
#  'JAK.48A_1.0': {2.0: 'Pam Jaya DKI',
#   3.0: 'KPP Pratama Tanah Abang Satu',
#   5.0: 'Polsek Tanah Abang',
#   6.0: 'Sbr. TPU Karet Bivak',
#   7.0: 'Jln. Karet Pasar Baru Timur II',
#   10.0: 'Sahid Sudirman Center',
#   12.0: 'Jln. Tiong',
#   13.0: 'Karet Pedurenan 2',
#   14.0: 'Satrio 6',
#   17.0: 'UPT. LLHD 2',
#   18.0: 'Puri Casablanca',
#   21.0: 'Telkom Tebet',
#   22.0: 'Sawo Kecik Raya',
#   16.0: 'Kuningan 18',
#   19.0: 'Kota Kasablanka',
#   20.0: 'Casablanca',
#   23.0: 'Masjid Jami Al Mamur Bukit Duri',
#   24.0: 'St. Tebet 2'},
#  'M1H_1.0': {0.0: 'Jak Lingko Tanah Abang 2',
#   2.0: 'Jln. Taman Jatibaru Timur',
#   3.0: 'Tanah Abang 2',
#   6.0: 'Kementerian ESDM',
#   7.0: 'Masjid Ar Rayyan Kementerian BUMN',
#   8.0: 'Dewan Pers',
#   9.0: 'DPRD DKI Jakarta',
#   10.0: 'Sbr. MNC Center',
#   5.0: 'Jembatan Serong',
#   11.0: 'St. Gondangdia 2'},
#  'JAK.02_1.0': {0.0: 'Duren Sawit',
#   2.0: 'Jln. Teluk Mandar 2',
#   6.0: 'Jln. Kejaksaan Pondok Bambu',
#   9.0: 'Simpang Pondok Bambu Batas 2',
#   11.0: 'Univ. Borobudur 2',
#   20.0: 'Gg. H. Bunen 2',
#   24.0: 'STMT Trisakti 2',
#   26.0: 'SPBU Jln. DI Panjaitan',
#   27.0: 'Jln. Otista III Komplek IV',
#   28.0: 'Ps. Kam 2',
#   29.0: 'Masjid Jami Attaubah 2',
#   30.0: 'Jln. Kb. Nanas Selatan II',
#   32.0: 'Simpang Otista III Selatan',
#   34.0: 'Bidara Cina 2',
#   14.0: 'Simpang Merak Cipinang Indah',
#   17.0: 'Masjid Al Akhbar PWI 2',
#   25.0: 'Penas Kalimalang 2',
#   31.0: 'Jln. Otista III Selatan',
#   33.0: 'STIS',
#   35.0: 'Klinik Otista',
#   36.0: 'Term. Kampung Melayu'},
#  '5D_0.0': {1.0: 'BKN',
#   2.0: 'BNN Arah Barat',
#   4.0: 'Cawang Otista',
#   5.0: 'Gelanggang Remaja',
#   7.0: 'Matraman Baru',
#   8.0: 'Slamet Riyadi',
#   9.0: 'Tegalan',
#   10.0: 'Matraman 1',
#   12.0: 'Salemba UI',
#   13.0: 'Kramat Sentiong',
#   15.0: 'Budi Utomo',
#   17.0: 'Jembatan Merah',
#   6.0: 'Bidara Cina',
#   14.0: 'Pal Putih',
#   16.0: 'Pasar Baru Timur',
#   18.0: 'Gunung Sahari Mangga Dua',
#   19.0: 'Pademangan',
#   20.0: 'Ancol'},
#  'JAK.44_1.0': {1.0: 'Gg. Sawo Jagakarsa',
#   3.0: 'St. Universitas Pancasila',
#   7.0: 'St. Lenteng Agung 2',
#   21.0: 'Jln. Pepaya V Jagakarsa',
#   24.0: 'Sbr. TK Rahmania Ragunan',
#   25.0: 'Sekolah Cita Buana',
#   34.0: 'Semar',
#   35.0: 'Andara Margasatwa 4',
#   5.0: 'Sbr. SMAN 38',
#   15.0: 'Jln. Raya Jagakarsa',
#   17.0: 'Sbr. Yayasan Al Azhar Syuhada',
#   26.0: 'Pemadam Jagakarsa',
#   36.0: 'Andara Margasatwa 1',
#   37.0: 'Jln. H. Terin Pangkalan Jati'},
#  '11Q_1.0': {2.0: 'Jatinegara RS Premier',
#   3.0: 'Masjid Jami Al Inayah',
#   5.0: 'Ps. Inpres Cipinang Besar',
#   8.0: 'Cipinang BKT',
#   11.0: 'Komplek Wijaya Kusuma 1',
#   13.0: 'Baladewa Residence',
#   15.0: 'Jln. Serdang',
#   19.0: 'Wisma Atlet Radin Inten',
#   20.0: 'Dinas Kebersihan Duren Sawit',
#   21.0: 'Buaran Plaza',
#   22.0: 'Taman Buaran Indah',
#   25.0: 'Penggilingan',
#   6.0: 'Hero Basuki Rahmat',
#   9.0: 'Masjid Jami At Taqwa 1',
#   14.0: 'Masjid Jami Al Barkah 1',
#   23.0: 'Flyover Radin Inten',
#   24.0: 'Perumnas Klender',
#   26.0: 'Walikota Jakarta Timur',
#   27.0: 'Pulo Gebang'},
#  'M5_1.0': {1.0: 'Pademangan',
#   2.0: 'Gunung Sahari Mangga Dua',
#   3.0: 'Jembatan Merah',
#   6.0: 'Pal Putih',
#   10.0: 'Matraman 1',
#   12.0: 'Slamet Riyadi',
#   4.0: 'Pasar Baru Timur',
#   5.0: 'Budi Utomo',
#   7.0: 'Kramat Sentiong',
#   13.0: 'Matraman Baru'},
#  '5B_0.0': {1.0: 'Masjid Attahiriyah',
#   2.0: 'Kampung Melayu Kecil',
#   4.0: 'RS Hermina',
#   5.0: 'Santa Maria',
#   6.0: 'Bukit Duri',
#   7.0: 'Pasar Jatinegara',
#   8.0: 'Jatinegara RS Premier',
#   9.0: 'Bidara Cina',
#   11.0: 'Cawang Otista',
#   12.0: 'BNN LRT',
#   10.0: 'Gelanggang Remaja',
#   13.0: 'BNN Arah Barat'},
#  'JAK.33_0.0': {0.0: 'Pulo Gadung 3',
#   9.0: 'Tirta Mas',
#   35.0: 'Sbr. Jembatan Sukamulya III',
#   63.0: 'Pangeran Jayakarta 1',
#   3.0: 'Kayu Mas',
#   25.0: 'Komplek Dittopad',
#   45.0: 'Jln. Angkasa 1',
#   66.0: 'KPP Pratama Tambora'},
#  '3F_0.0': {0.0: 'Gelora Bung Karno',
# ...
#   69.0: 'Sbr. Panti Asuhan Putera Mulia',
#   73.0: 'St. LRT Pulo Mas 3',
#   77.0: 'Pulo Gadung 3'},
#  '3A_1.0': {0.0: 'Kalideres 1',
#   2.0: 'Pertamina Kalideres Daan Mogot',
#   3.0: 'Pesakih 1',
#   4.0: 'Rusun Pesakih'},
#  '7E_0.0': {1.0: 'SMPN 188',
#   5.0: 'Supriyadi',
#   6.0: 'Jln. Makmur',
#   16.0: 'Phe Tower Kebagusan',
#   18.0: 'Kebagusan Raya',
#   19.0: 'Kementan',
#   11.0: 'Muara Dalam',
#   17.0: 'Plaza Oleos',
#   20.0: 'Departemen Pertanian',
#   21.0: 'Ragunan'},
#  'JAK.30_1.0': {6.0: 'Komplek DPR III Meruya Selatan',
#   9.0: 'Simpang Meruya Selatan Saaba',
#   10.0: 'Midi Utama Meruya Selatan 2',
#   11.0: 'Sbr. Univ. Mercu Buana',
#   14.0: 'Jln. Kartika Meruya Selatan',
#   15.0: 'Sbr. Jln. Manunggal Meruya Selatan',
#   18.0: 'SDN Meruya Utara 02 Pagi',
#   34.0: 'Sbr. RS Siloam Kb. Jeruk',
#   38.0: 'Apartemen Kedoya Elok 2',
#   42.0: 'SMKN 60',
#   43.0: 'Kel. Duri Kepa',
#   45.0: 'Sbr. Jln. H. Sanusi Taming',
#   28.0: 'Simpang Meruya Ilir 1',
#   40.0: 'Simpang Panjang Duri Kepa',
#   46.0: 'Jln. Jeruk Garut',
#   47.0: 'Simpang Ps. Patra 2',
#   51.0: 'Jln. Tj. Duren Utara V',
#   53.0: 'Sbr. Masjid Nurul Falah Grogol',
#   54.0: 'Term. Grogol'},
#  'JAK.56_1.0': {2.0: 'SDN Kelapa Dua 01',
#   7.0: 'Jln. Daud I Sukabumi Utara',
#   13.0: 'Jln. Palmerah Barat IV',
#   17.0: 'Ps. Bintang Mas 1',
#   18.0: 'Masjid Jami Nurul Iman Palmerah',
#   43.0: 'GBI Sungai Yordan',
#   45.0: 'Sbr. Sekolah Pelita II Kb. Jeruk',
#   46.0: 'Simpang Gg. Macan Daan Mogot',
#   51.0: 'Sbr. Jln. R. Anggun',
#   22.0: 'Jln. Komplek Migas V Palmerah',
#   29.0: 'Simpang Budi Sakti Raya',
#   37.0: 'Simpang Tj. Duren Barat 2',
#   49.0: 'Pesing Polgar 1',
#   52.0: 'St. Pesing',
#   54.0: 'Jln. Taman Surya I',
#   57.0: 'Term. Grogol'},
#  '8E_0.0': {1.0: 'Bintaro Gg. Masjid',
#   6.0: 'SMA Kartika',
#   10.0: 'Kolong Tol Jakarta Serpong 2',
#   16.0: 'Pertamina Bina Medika',
#   19.0: 'Kantor Pos Kebayoran Lama',
#   23.0: 'Pasar Kebayoran Lama',
#   26.0: 'Puskesmas Kel. Gunung',
#   11.0: 'Kolong Tol Guru Saleh',
#   21.0: 'Perlintasan Kereta Api Kebayoran',
#   27.0: 'Mayestik 2',
#   28.0: 'RS Pusat Pertamina 2',
#   29.0: 'RS Pusat Pertamina 3',
#   30.0: 'CSW 2'},
#  '1R_0.0': {0.0: 'Term. Senen',
#   1.0: 'Gunung Agung',
#   3.0: 'Balai Kota 1',
#   6.0: 'JPO Blok E',
#   7.0: 'Pharmin',
#   8.0: 'Explorer Tanah Abang',
#   9.0: 'Blok F',
#   11.0: 'JPO Blok G',
#   12.0: 'Jak Lingko Tanah Abang 2'},
#  'JAK.45_0.0': {8.0: 'Simpang Gunung Balong Karang Tengah',
#   10.0: 'Sbr. Kel. Lebak Bulus',
#   15.0: 'Dapsus 2',
#   19.0: 'BBPK Jakarta',
#   20.0: 'Komplek DDN 1',
#   21.0: 'Sbr. Sekolah Charitas Pondok Labu',
#   26.0: 'Sbr. Gg. H Ahmad Nado',
#   35.0: 'Sbr. Puri Margasatwa',
#   40.0: 'Gg. Musholla Ragunan',
#   43.0: 'Ragunan 2',
#   14.0: 'Sbr. Jln. Pondok Labu 1A',
#   23.0: 'Sbr. Jln. Pinang IV Pondok Labu',
#   24.0: 'Jln. Pinang VI Pondok Labu',
#   27.0: 'Simpang Tridharma Bango Raya',
#   28.0: 'Yayasan Panti Nugraha',
#   32.0: 'Sbr. Semar',
#   33.0: 'Jln. Wisma Semar',
#   37.0: 'Simpang Kampung Kandang 2',
#   42.0: 'Gg. Tamansari Ragunan',
#   44.0: 'Term. Ragunan'},
#  'JAK.11_0.0': {8.0: 'Pospol Jati Bunder',
#   11.0: 'Hotel Kalisma KS Tubun',
#   14.0: 'Sbr. RS Pelni Petamburan',
#   15.0: 'DPP FPI',
#   18.0: 'Sbr. RS Bhakti Mulia',
#   20.0: 'Sbr. Jln. Palmerah Utara II',
#   22.0: 'Ps. Palmerah 2',
#   36.0: 'SDN Grogol Utara 03',
#   38.0: 'RS Medika Permata Hijau 4',
#   40.0: 'Jln. Limo Grogol Utara',
#   45.0: 'Sbr. SMPN 48',
#   27.0: 'Sbr. SDN Palmerah 09',
#   30.0: 'Jln. Kemandoran VI Grogol Utara',
#   31.0: 'Jln. Kemandoran VII Grogol Utara',
#   41.0: 'Sbr. Kimia Farma Grogol Utara',
#   43.0: 'Sbr. SDN Grogol Selatan 01',
#   46.0: 'Ruko Ps. Kebayoran Lama',
#   47.0: 'St. Kebayoran 2'},
#  'JAK.27_0.0': {1.0: 'Pintu Exit Term. Pulo Gebang',
#   2.0: 'Flyover Pulo Gebang 1',
#   10.0: 'Sbr. Komarudin Timur Lingkar Timur',
#   13.0: 'Sbr. YPI Asyaadah',
#   14.0: 'Simpang Pangeran Komarudin 1',
#   16.0: 'Jln. Kayu Tinggi',
#   17.0: 'Masjid Al Barkah 2',
#   21.0: 'Gempol Baru 2',
#   39.0: 'Perum Rorotan Mas',
#   42.0: 'Perum Mutiara Indah Rorotan',
#   45.0: 'Masjid At Taqwa Karang Tengah',
#   47.0: 'Simpang KH Abdulloh Karang Tengah 1',
#   27.0: 'Jln. Sentosa Tambun Rengas',
#   32.0: 'Sbr. Tambun Utara',
#   34.0: 'Sbr. Komplek Sltp 200',
#   40.0: 'Sbr. Masjid Jami Ar Roghibin',
#   44.0: 'Simpang Kaliabang Rorotan 1',
#   48.0: 'Rorotan BKT'},
#  'M13_0.0': {0.0: 'Puri Beta 2',
#   1.0: 'Puri Beta 1',
#   4.0: 'Swadarma',
#   5.0: 'Cipulir',
#   6.0: 'Seskoal',
#   7.0: 'Kebayoran Lama',
#   8.0: 'Mayestik',
#   11.0: 'Rawa Barat',
#   9.0: 'CSW 1',
#   10.0: 'Tirtayasa',
#   12.0: 'Tendean'},
#  '12_1.0': {1.0: 'Landmark Pluit Auto Plaza',
#   3.0: 'Gedong Panjang',
#   4.0: 'Museum Fatahillah',
#   8.0: 'Gunung Sahari Mangga Dua',
#   10.0: 'Kemayoran Landas Pacu Timur',
#   11.0: 'Danau Agung',
#   13.0: 'Sunter Karya',
#   15.0: 'Sunter Kelapa Gading Arah Utara',
#   18.0: 'Permai Koja Arah Utara',
#   19.0: 'Enggano',
#   14.0: 'Sunter Boulevard Barat',
#   17.0: 'Walikota Jakarta Utara Arah Utara',
#   20.0: 'Tanjung Priok'},
#  'D11_1.0': {3.0: 'Gg. Saminten',
#   4.0: 'Pesona Square',
#   5.0: 'Moch Yusuf Raya 2',
#   6.0: 'STIAMI 2',
#   7.0: 'Pesona Khayangan',
#   8.0: 'Gg. Beringin',
#   9.0: 'ACE Hardware',
#   11.0: 'Balaikota Depok 2',
#   12.0: 'Term. Depok Baru'},
#  'JAK.04_0.0': {0.0: 'Kusuma Timur Vihara Dharma Bhakti',
#   1.0: 'Ruko Taman Duta Mas',
#   5.0: 'Jln. Indraloka Gg. VIII',
#   9.0: 'Jln. Hadiah Utama II',
#   13.0: 'Bunda Hati Kudus Jelambar',
#   6.0: 'Sekretariat 06 Wijaya Kusuma',
#   7.0: 'Simpang Indraloka 2',
#   15.0: 'Term. Grogol'},
#  '9_0.0': {8.0: 'Pancoran Tugu Arah Barat',
#   13.0: 'Semanggi',
#   20.0: 'Latumeten Stasiun Grogol Arah Utara',
#   22.0: 'Jembatan Dua',
#   23.0: 'Penjaringan',
#   17.0: 'RS Harapan Kita Arah Utara',
#   24.0: 'Penjaringan',
#   24.5: 'Pluit'},
#  '11C_1.0': {0.0: 'Rusun Pulo Gebang',
#   1.0: 'Simpang Tiga Pulo Gebang Raya',
#   2.0: 'Pintu Exit Term. Pulo Gebang',
#   3.0: 'Raya Pulo Gebang Akses St. Cakung',
#   4.0: 'Walikota Jakarta Timur 2',
#   8.0: 'At Thahiriah 1',
#   9.0: 'Simpang Kampung Jembatan 1',
#   10.0: 'SMK Ristek Kikin',
#   12.0: 'Gg. Sawo 1',
#   14.0: 'Perum Tpi 1',
#   6.0: 'Penggilingan 1',
#   13.0: 'Gg. Aim 1',
#   15.0: 'Rusun Pinus Elok Blok A'},
#  'JAK.51_1.0': {1.0: 'Sbr. St. Taman Kota',
#   4.0: 'Sbr. Jln. B Basmol Raya',
#   5.0: 'Sbr. Jln. Al Hidayah Basmol',
#   7.0: 'Jln. Kampung Baru',
#   8.0: 'Gg. H Satiri Manshur',
#   14.0: 'Jln. H Briti B',
#   26.0: 'Simpang Permata Meruya 2',
#   33.0: 'Sbr. RPTRA Menara',
#   41.0: 'SMPN 245',
#   12.0: 'Perum Kedoya Garden',
#   24.0: 'Masjid Nurul Iman Kubur Batu',
#   32.0: 'Jln. Mawar Kav DKI',
#   35.0: 'Sbr. Cek & Ricek',
#   40.0: 'Simpang Kejaksaan H. Muchtar Raya',
#   42.0: 'Ponpes Musyarrofah',
#   44.0: 'Jln. SMAN 63',
#   47.0: 'Sulaiman'},
#  'JAK.112_0.0': {5.0: 'Boulevard Janur Elok Raya 1',
#   6.0: 'Jln. Kelapa Nias IV',
#   8.0: 'Masjid Raya Al Musyawarah Kelapa Gading 2',
#   9.0: 'Sbr. Ps. Mandiri Kelapa Gading',
#   14.0: 'Jln. Gading Mas Barat IV',
#   16.0: 'Sbr. Jln. Tari Klasik',
#   17.0: 'Simpang Jln. Bongo Raya',
#   18.0: 'Sbr. Jln. Pendet',
#   23.0: 'Sbr. Masjid Al Mumin',
#   24.0: 'Taman Maramba',
#   15.0: 'Sbr. Jln. Primanota',
#   20.0: 'SDN Pegangsaan Dua 07',
#   21.0: 'Sbr. SDN Pegangsaan Dua 07',
#   22.0: 'Simpang Seruling Musik Raya',
#   25.0: 'Sbr. TPA As Sholihin',
#   26.0: 'Pulo Gadung 5'},
#  'JAK.34_0.0': {3.0: 'Simpang Nusa Indah VI',
#   4.0: 'RS Islam Pondok Kopi',
#   6.0: 'Bimbel Calistung',
#   23.0: 'Jln. Bulak Barat V Klender',
#   28.0: 'Jln. Arus Jati',
#   35.0: 'Klinik Hemodialisa Pandaoni Medika',
#   37.0: 'Simpang Ps. Rawamangun',
#   22.0: 'Sbr. Panti Asuhan Anak Putra Utama 1',
#   25.0: 'Flyover Klender 2',
#   29.0: 'Pool Hiba Utama 2',
#   32.0: 'Sbr. Makam Pangeran Jayakarta',
#   39.0: 'Total Buah Rawamangun',
#   40.0: 'St. LRT Velodrome 2',
#   41.0: 'St. LRT Velodrome 1',
#   42.0: 'Simpang Arion'},
#  'JAK.25_1.0': {3.0: 'Sbr. Komplek Lapan Pekayon',
#   9.0: 'Sbr. Jln. Damai Kalisari',
#   11.0: 'Sbr. Pesona Kalisari',
#   12.0: 'Kel. Kalisari',
#   16.0: 'Jln. Manunggal Bakti Kalisari',
#   21.0: 'Tribuana',
#   23.0: 'Kantor Kelurahan Baru',
#   27.0: 'Sbr. Gg. Wali Pertama Cijantung',
#   29.0: 'Simpang Pondok Baru Gongseng Raya',
#   7.0: 'Simpang Kalisari Raya Lapan',
#   26.0: 'Simpang Pertengahan Cijantung',
#   30.0: 'Sekolah Malahayati',
#   33.0: 'Jln. Pule I Cijantung',
#   35.0: 'Sbr. Masjid Raya Baitul Muttaqin',
#   38.0: 'Sekolah Islam PB Soedirman',
#   42.0: 'RS Jantung Binawaluya',
#   47.0: 'Term. Kampung Rambutan'},
#  'JAK.32_1.0': {3.0: 'Sbr. MI Nurul Hakim',
#   11.0: 'Jln. Anggrek Petukangan',
#   12.0: 'Sbr. TK Tunas Harapan',
#   17.0: 'Sbr. HKBP Petukangan',
#   26.0: 'Sbr. Gg. Asmat Petukangan',
#   33.0: 'Sbr. SMK Kartika X-2',
#   34.0: 'Sbr. SD Kartika X-2',
#   35.0: 'SMPN 235',
#   43.0: 'Masjid Hifdzirrahim',
#   57.0: 'Darul Aitam Pondok Pinang',
#   61.0: 'RA Kartini',
#   19.0: 'Simpang Sabar Raya Petukangan 2',
#   38.0: 'Sbr. Rumkitban Bintaro',
#   44.0: 'Jln. H. Gari',
#   45.0: 'Kolong Tol Jakarta Serpong 2',
#   47.0: 'Jln. Guru Saleh',
#   58.0: 'SMK Averus Pondok Pinang',
#   60.0: 'Sbr. Fedex Pondok Pinang',
#   62.0: 'Poins Square',
#   63.0: 'Lebak Bulus Jak Lingko'},
#  'JAK.32_0.0': {7.0: 'Ruko Pondok Pinang Centre',
#   10.0: 'Simpang Deplu Veteran Raya',
#   12.0: 'Sbr. RS Dr Suyoto',
#   18.0: 'Flyover Bintaro',
#   26.0: 'Yon Arhanud - 10 Pesanggrahan',
#   35.0: 'Sbr. Klinik Yadika Petukangan',
#   38.0: 'Mushola Nurul Huda Petukangan',
#   45.0: 'Simpang Sabar Raya Petukangan 1',
#   47.0: 'Adam Malik 1',
#   50.0: 'Jln. H. Jimin Petukangan',
#   19.0: 'Kolong Tol Jakarta Serpong 1',
#   39.0: 'Jln. Manunggal II Petukangan',
#   42.0: 'Simpang Sabar Raya 1',
#   43.0: 'Jln. Sabar 1 Petukangan',
#   51.0: 'TK Tunas Harapan',
#   52.0: 'Jln. AMD Manunggal V'},
#  'JAK.118_0.0': {2.0: 'Jln. Bisma Raya 2',
#   3.0: 'BNN Jakarta Utara',
#   5.0: 'SDN Sunter Agung 09',
#   6.0: 'Pengadilan Negeri Jakut',
#   7.0: 'Sbr. Jembatan Item',
#   14.0: 'Jln. Bahari Raya 2',
#   18.0: 'Sbr. SDN Pademangan 03',
#   25.0: 'Jln. Hidup Baru',
#   26.0: 'Pintu Air Kalimati',
#   28.0: 'Mangga Dua Square',
#   31.0: 'Ruko Mall Mangga Dua',
#   32.0: 'Gg. Burung Dalam',
#   33.0: 'Pangeran Jayakarta 1',
#   38.0: 'Simpang Kopi Kali Besar Barat',
#   19.0: 'Sbr. SDN Pademangan Timur 05 07',
#   21.0: 'Sbr. SMKN 23',
#   22.0: 'Puskesmas Kelurahan Pademangan Timur',
#   27.0: 'Gunung Sahari Mangga Dua Barat',
#   36.0: 'Simpang Kali Besar Barat',
#   37.0: 'Kali Besar Barat 1',
#   39.0: 'Term. Kota Intan'},
#  'JAK.03_0.0': {1.0: 'Jln. Grafika',
#   4.0: 'Batan H Kaman',
#   6.0: 'Jln. Pertanian II',
#   11.0: 'Jln. Karang Tengah Raya',
#   16.0: 'Sbr. Sekolah Keperawatan YPDR',
#   17.0: 'Al Izhar Pondok Labu 2',
#   18.0: 'Sekolah Darussalam H. Ipin',
#   20.0: 'Graha Werdatama Pondok Labu',
#   23.0: 'Simpang DDN Pondok Labu',
#   22.0: 'Jln. Pinang II Pondok Labu',
#   24.0: 'Sbr. Akper Fatmawati Pondok Labu',
#   27.0: 'Jln. Andara Raya'},
#  '10B_0.0': {0.0: 'Rusun Cipinang Besar Selatan',
#   1.0: 'TPU Kb. Nanas 2',
#   2.0: 'STMT Trisakti 2',
#   3.0: 'Penas Kalimalang 2'},
#  '13B_1.0': {0.0: 'Pancoran Barat Arah Timur',
#   2.0: 'Tendean',
#   6.0: 'Mayestik',
#   8.0: 'Kebayoran Lama',
#   10.0: 'Cipulir',
#   11.0: 'Swadarma',
#   12.0: 'JORR',
#   4.0: 'Tirtayasa',
#   9.0: 'Seskoal',
#   13.0: 'Adam Malik',
#   14.0: 'Puri Beta 2'},
#  'JAK.43B_0.0': {1.0: 'Sbr. SMAN 8',
#   2.0: 'Sbr. Klinik Firdausy',
#   5.0: 'SMA Islam As Syafiiyah 01',
#   8.0: 'Sbr. Mushola Al Hidayah Bukit Duri',
#   11.0: 'Gebu Minang',
#   13.0: 'Sbr. Kel. Tebet Timur',
#   14.0: 'Jln. Tebet Timur Dalam III',
#   19.0: 'Sbr. Jln. Cikoko Timur I',
#   26.0: 'Yayasan Mambaul Ula',
#   27.0: 'PGC',
#   4.0: 'Simpang Bukit Duri Selatan 1',
#   21.0: 'Sbr. Lapangan Blok O Pengadegan',
#   22.0: 'Ps. Kaget Pengadegan',
#   23.0: 'St. Duren Kalibata 4',
#   24.0: 'St. Duren Kalibata 2',
#   25.0: 'Pertigaan Dewi Sartika',
#   28.0: 'PGC Dalam'},
#  '5B_1.0': {0.0: 'BNN Arah Barat',
#   1.0: 'BNN LRT',
#   5.0: 'Flyover Kampung Melayu',
#   6.0: 'Kampung Melayu Besar 2',
#   3.0: 'Gelanggang Remaja',
#   7.0: 'St. Tebet 1'},
#  'JAK.54_0.0': {6.0: 'Sekolah Lemuel',
#   11.0: 'Jln. KS Tubun II',
#   13.0: 'Koramil Jln. Brigjen Katamso',
#   15.0: 'Wisma 77',
#   16.0: 'Flyover Slipi Kemanggisan',
#   24.0: 'Sbr. Jln. Rasamala Dalam',
#   26.0: 'Sbr. Jln. Rawa Kepa IX',
#   28.0: 'Simpang Mandala Selatan Raya',
#   23.0: 'Kel. Jati Pulo',
#   25.0: 'Pospol Tomang 2',
#   27.0: 'Sbr. SMPN 286',
#   29.0: 'STIE IBEK',
#   31.0: 'Jln. Tomang Tinggi Gg. 1',
#   32.0: 'Roxy Square 2'},
#  'JAK.35_0.0': {0.0: 'Pool Pangkalan Jati',
#   2.0: 'Pangkalan Jati 2',
#   7.0: 'Jln. Pangkalan Jati VI A',
#   11.0: 'Pospol Makasar',
#   12.0: 'Taman Pangkalan Jati Kalimalang',
#   13.0: 'Sekolah Tunas Cemerlang',
#   16.0: 'Komplek Wijaya Kusuma 2',
#   18.0: 'Sbr. Balai Rakyat',
#   22.0: 'Sbr. Ps. Klender',
#   26.0: 'Transjakarta Pool Klender',
#   36.0: 'SMK Tunas Markatin',
#   17.0: 'Jln. Melati Bhakti',
#   20.0: 'Jln. Cipinang Muara III',
#   28.0: 'Sbr. Makam Pangeran Jayakarta',
#   31.0: 'Klinik Hemodialisa Pandaoni Medika',
#   32.0: 'Sbr. Gereja Kristen Jawa',
#   33.0: 'Apotik Rini Rawamangun',
#   34.0: 'Sbr. Rukan Balai Pustaka',
#   35.0: 'Simpang Balai Pustaka Timur Waru',
#   37.0: 'Total Buah Rawamangun'},
#  'JAK.21_0.0': {3.0: 'Dinas Lingkungan Hidup',
#   5.0: 'Jasa Marga Cililitan 2',
#   6.0: 'Gg. Siluman Cililitan Besar',
#   10.0: 'TPU Kb. Pala 2',
#   15.0: 'Gg. Pos Komodor Halim',
#   18.0: 'TK Angkasa 5',
#   19.0: 'Sbr. Gereja Oikumene',
#   22.0: 'RSAU Dr Esnawan Antariska 2',
#   24.0: 'Sbr. Slb Angkasa',
#   20.0: 'Pos Jaga Utama 2',
#   21.0: 'Griya Ardhya Garini 2',
#   25.0: 'Sbr. SD Angkasa 1',
#   26.0: 'Sbr. SMK Angkasa 2',
#   29.0: 'Masjid Darul Huda 1'},
#  '7_0.0': {1.0: 'Tanah Merdeka Arah Barat',
#   4.0: 'Pasar Induk Kramat Jati',
#   5.0: 'Pasar Kramat Jati',
#   6.0: 'PGC 1',
#   7.0: 'BKN',
#   11.0: 'Cawang Otista',
#   8.0: 'Cawang UKI',
#   12.0: 'Gelanggang Remaja',
#   13.0: 'Bidara Cina'},
#  'JAK.99_0.0': {0.0: 'Pulo Gadung 5',
#   4.0: 'Sbr. PTC Pulo Gadung',
#   7.0: 'Al-Wathoniyah',
#   14.0: 'Masjid Al-Marzuqiyah',
#   15.0: 'Jln. Anggrek Raya',
#   17.0: 'Gg. H Sayuti I',
#   18.0: 'Carrefour Buaran',
#   19.0: 'SMKN 48',
#   23.0: 'Wira Purusa',
#   32.0: 'Billy Moon',
#   34.0: 'Jln. Klp. Hijau',
#   21.0: 'Kasi Dikdas 2',
#   24.0: 'Rukan Radin Inten II',
#   27.0: 'Simpang Radin Inten II Kalimalang',
#   29.0: 'Curug Kalimalang',
#   30.0: 'Kav Marinir Kalimalang',
#   35.0: 'Jln. Inspeksi Kalimalang Lampiri'},
#  '13D_0.0': {2.0: 'Adam Malik',
#   6.0: 'Seskoal',
#   7.0: 'Kebayoran Lama',
#   9.0: 'CSW 1',
#   10.0: 'Tirtayasa',
#   17.0: 'Buncit Indah',
#   18.0: 'Pejaten',
#   11.0: 'Rawa Barat',
#   12.0: 'Tendean',
#   19.0: 'Jati Padang',
#   22.0: 'Ragunan'},
#  '5F_1.0': {0.0: 'Masjid Jami Al Makmur 2',
#   1.0: 'Masjid Jami Al Makmur 1',
#   2.0: 'Sbr. RSUD Tanah Abang',
#   5.0: 'Yayasan Muhammadiyah 1',
#   8.0: 'London School',
#   9.0: 'City Walk Sudirman',
#   12.0: 'Karet Pedurenan 2',
#   16.0: 'UPT. LLHD 2',
#   19.0: 'Casablanca',
#   20.0: 'Telkom Tebet',
#   22.0: 'Kampung Melayu Kecil',
#   24.0: 'Kampung Melayu Besar 2',
#   10.0: 'Sahid Sudirman Center',
#   14.0: 'Ambassador',
#   15.0: 'Kuningan 18',
#   21.0: 'Sawo Kecik Raya',
#   23.0: 'Flyover Kampung Melayu',
#   25.0: 'St. Tebet 3'},
#  '5N_1.0': {10.0: 'Kav Polri Blok H Jagakarsa',
#   11.0: 'Kav Polri Blok E Jagakarsa',
#   12.0: 'Sekolah Cita Buana',
#   14.0: 'Gg. Harapan I Jagakarsa',
#   21.0: 'Sbr. Cilandak KKO',
#   29.0: 'Pertigaan Pejaten Barat',
#   43.0: 'Transvision',
#   47.0: 'Tebet Barat Dalam',
#   50.0: 'Merpati',
#   17.0: 'SDN Cilandak Timur 01',
#   32.0: 'Sbr. Jln. Kemang Timur XVII',
#   33.0: 'Sbr. Jln. Kemang Timur XI',
#   46.0: 'Pancoran Soepomo',
#   54.0: 'Simpang Tebet Barat Raya',
#   58.0: 'Cervino Village',
#   63.0: 'Sawo Kecik Raya',
#   64.0: 'Kampung Melayu Kecil'},
#  'S21_1.0': {0.0: 'Kejaksaan Agung',
#   1.0: 'St. MRT Blok M 1',
#   3.0: 'Kramat Pela',
#   4.0: 'Antena III',
#   5.0: 'LPP RRI 2',
#   6.0: 'Jln. KRI Harimau',
#   11.0: 'Jln. H. Ahmad',
#   12.0: 'Margaguna 2',
#   15.0: 'Lebak Bulus',
#   17.0: 'UMJ 2',
#   19.0: 'Situ Gintung 1',
#   20.0: 'Situ Gintung 2',
#   24.0: 'Polsek Ciputat 2',
#   25.0: 'Pusdiklat Kemenag 2',
#   26.0: 'Ps. Ciputat',
#   27.0: 'Pom Bensin Ciputat',
#   13.0: 'Pondok Indah 2',
#   14.0: 'Pondok Indah 1',
#   18.0: 'Komplek Mandiri Giant Express 2',
#   22.0: 'Kampus Uin 2',
#   23.0: 'Komplek Uin',
#   28.0: 'Pool PPD Ciputat'}}

# %% [markdown]
# Matching the dictionary into the DataFrame

# %%
def find_combined_key(row, combined_dict):
    for outer_key, inner_dict in combined_dict.items():
        if row['stopStartSeq'] in inner_dict and inner_dict[row['stopStartSeq'] == row['tapInStopsName']]:
            return outer_key
        return row['corridorID']

tj['corridorID'] = tj.apply(find_combined_key, axis=1, combined_dict=combined_dict)

# %%
tj.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID           981
# corridorName        1125
# direction              0
# tapInStops            22
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops          131
# tapOutStopsName      122
# tapOutStopsLat       122
# tapOutStopsLon       122
# stopEndSeq           122
# tapOutTime          1344
# payAmount           1007
# composite_key          0
# dtype: int64

# %% [markdown]
# Rematching the corridorName with the newly found corridorID

# %%
# Making a pivot table, since the corridorName has lower count, there should be a corridorName with multiple corridorID
data_stasiun_count = pd.pivot_table(data = tj,
               index = ['corridorName','corridorID'],
               values = 'tapInStopsLat',
               aggfunc= 'count').sort_values(by=['tapInStopsLat'], ascending=False).reset_index().rename(columns={'tapInStopsLat': 'Used'})
data_stasiun_count.drop_duplicates(subset='corridorID', inplace=True)

tj['corridorName'] = tj['corridorName'].fillna(
    tj['corridorID'].str.upper().map(data_stasiun_count.set_index('corridorID')['corridorName'])
)

# %%
tj.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID           981
# corridorName         981
# direction              0
# tapInStops            22
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops          131
# tapOutStopsName      122
# tapOutStopsLat       122
# tapOutStopsLon       122
# stopEndSeq           122
# tapOutTime          1344
# payAmount           1007
# composite_key          0
# dtype: int64

# %% [markdown]
# ## **Data Distribution & Outliers**

# %% [markdown]
# Since all of the data presented in our data source is categorical nominal, we do not need to check the data distribution nor do we have to do normality test to check whether the data is normally distributed or not. Because of that, we also do not have outliers. The only numeric data we have is the Pay Amount, but even then it only contains numeric discreet values.

# %%
tj[tj['payAmount'] == 0]
# Out:
#               transID            payCardID payCardBank  \
# 6      HEMW326B9N91TV      213155822653833      emoney
# 7      XTKE052E5E87LN     3587341902618993         dki
# 14     LZFD368Q3E81HJ        4056836188316      online
# 19     ZYRL615G4C05RD     5430018591726410         dki
# 21     ZJVI960B9I42DA      343851798729291      emoney
# ...               ...                  ...         ...
# 37891  XQDZ821C9G88JD     2712823212983860         dki
# 37892  YHJT665I6G08OS        4775206940093      online
# 37893  GNET512K3A93CA     3500965207195341         dki
# 37894  ZXVG342K6T27GU  4475487986105118550      brizzi
# 37898  RGVK175U2U98UV      377840859133591      emoney
#
#                       payCardName payCardSex  payCardBirthDate corridorID  \
# 6           R. Devi Hariyah, S.T.          M              1974     JAK.18
# 7                 Darmanto Rajasa          F              1991        NaN
# 14                   Nadine Utami          M              1975     JAK.46
# 19                  Karna Waskita          M              1981     JAK.88
# 21                   Garang Utama          F              1997     JAK.16
# ...                           ...        ...               ...        ...
# 37891    drg. Maras Wibowo, S.Ked          F              1966     JAK.30
# 37892       Cahyo Sudiati, M.Farm          M              1979     JAK.52
# 37893            Latika Salahudin          F              2000     JAK.80
# 37894  Tgk. Dipa Purnawati, S.E.I          F              2012     JAK.39
# 37898                Ana Agustina          M              1976     JAK.13
#
#                                     corridorName  direction tapInStops  \
# 6                            Kalibata - Kuningan        0.0    B00243P
# 7                                            NaN        1.0    B03416P
# 14                      Pasar Minggu - Jagakarsa        1.0    B00608P
# 19          Terminal Tanjung Priok - Ancol Barat        0.0    B00722P
# 21                            Cililitan - Condet        0.0    B02144P
# ...                                          ...        ...        ...
# 37891                   Grogol - Meruya via Roxy        1.0    B01209P
# 37892  Terminal Kalideres - Terminal Muara Angke        1.0    B01087P
# 37893                  Rawa Buaya - Rawa Kompeni        0.0    B02485P
# 37894                   Kalimalang - Duren Sawit        0.0    B04489P
# 37898                Tanah Abang - Jembatan Lima        1.0    B02505P
#
#                        tapInStopsName  tapInStopsLat  tapInStopsLon  \
# 6                     Cervino Village      -6.224355      106.85165
# 7                  SDN Pondok Labu 11      -6.313269      106.80221
# 14     Gelanggang Remaja Pasar Minggu      -6.284615      106.83787
# 19     Gunung Sahari Mangga Dua Timur      -6.137032      106.83254
# 21             Lippo Mall Kramat Jati      -6.270835      106.86741
# ...                               ...            ...            ...
# 37891     Jln. Kartika Meruya Selatan      -6.203099      106.73673
# 37892        Jln. Gunung Galunggung 1      -6.142286      106.73712
# 37893                         MTsN 37      -6.097910      106.70237
# 37894                   Sbr. SMPN 252      -6.239289      106.94229
# 37898                  Museum Textile      -6.188656      106.80954
#
#        stopStartSeq            tapInTime tapOutStops  \
# 6                25  2023-04-03 06:58:21     B04699P
# 7                 2  2023-04-03 06:44:24     B00899P
# 14                5  2023-04-03 05:38:44     B01062P
# 19               20  2023-04-03 06:43:49     B05989P
# 21                4  2023-04-03 05:08:36     B01393P
# ...             ...                  ...         ...
# 37891            14  2023-04-19 16:31:09     B04071P
# 37892            29  2023-04-28 16:38:56     B03207P
# 37893            39  2023-04-19 08:16:10     B03053P
# 37894            27  2023-04-14 11:36:12     B01624P
# 37898            33  2023-04-15 19:59:26     B01787P
#
#                        tapOutStopsName  tapOutStopsLat  tapOutStopsLon  \
# 6         Simpang Al Barkah Dr Saharjo       -6.220395       106.84653
# 7                           Jln. Baros       -6.311046       106.78400
# 14                     Jln. Gabus Raya       -6.301222       106.83623
# 19                  Jln. Ancol Barat 6       -6.124810       106.81983
# 21               Jln. Mesjid Al Mabruk       -6.284350       106.85293
# ...                                ...             ...             ...
# 37891   Sbr. Masjid Nurul Falah Grogol       -6.170757       106.78477
# 37892                  RSUD Cengkareng       -6.142238       106.73398
# 37893          Puskesmas Kel. Kamal II       -6.100938       106.69786
# 37894  Jln. Swakarsa III Pondok Kelapa       -6.244759       106.94249
# 37898                       JPO Blok G       -6.188861       106.81135
#
#        stopEndSeq           tapOutTime  payAmount                composite_key
# 6            40.0                  NaN        0.0      213155822653833_B00243P
# 7            12.0  2023-04-03 07:11:43        0.0     3587341902618993_B03416P
# 14           17.0  2023-04-03 06:09:17        0.0        4056836188316_B00608P
# 19           36.0  2023-04-03 07:30:45        0.0     5430018591726410_B00722P
# 21           20.0  2023-04-03 05:30:45        0.0      343851798729291_B02144P
# ...           ...                  ...        ...                          ...
# 37891        53.0  2023-04-19 19:13:53        0.0     2712823212983860_B01209P
# 37892        30.0  2023-04-28 18:35:16        0.0        4775206940093_B01087P
# 37893        42.0  2023-04-19 10:32:30        0.0     3500965207195341_B02485P
# 37894        35.0  2023-04-14 13:15:25        0.0  4475487986105118550_B04489P
# 37898        34.0  2023-04-15 20:27:50        0.0      377840859133591_B02505P
#
# [16648 rows x 23 columns]

# %% [markdown]
# Almost half of the data have a payAmount of 0, to get a price of Rp. 0, Indonesia citizens have to fulfill one of 15 conditions including, civil worker, elderly, disabled, etc.
# for the one with the price of Rp. 20.000, that is for a different type of transjakarta bus, called RoyalTrans which consist of only less than 5% of data

# %%
tj[tj['payAmount'] == 20000]
# Out:
#               transID         payCardID payCardBank  \
# 5      DDES630K2F80KC  2251412124634980         dki
# 8      OIHS248V7S72EB  6510013988638519         dki
# 60     RHUT145C1U25ZY     4290559479079      online
# 70     OTGH855B8A29BP  3549158005951908         dki
# 117    YTOA058V9U73VN     4709994160903      online
# ...               ...               ...         ...
# 37854  AMQA420I2P82KP  3553882732550120         dki
# 37878  FFUS474T7Q54QF    36067042340502         bni
# 37879  LVSU593P5B50VF    30480183587078         bni
# 37888  KWQA944F9O89IN  6585885975007109         dki
# 37897  YXPP627N4G95HO   213159426675861      emoney
#
#                          payCardName payCardSex  payCardBirthDate corridorID  \
# 5                      Tirta Siregar          F              1993         1T
# 8             Cagak Maheswara, S.Sos          F              1992     3C_1.0
# 60                      Lutfan Hakim          M              2011        T21
# 70         Mustofa Wijayanti, M.Farm          M              1981         1T
# 117    Cut Gabriella Haryanti, S.Sos          M              1974        T21
# ...                              ...        ...               ...        ...
# 37854                   Siti Rahimah          M              1994         6P
# 37878                 Jatmiko Mansur          F              1965        D32
# 37879   Hj. Julia Nainggolan, M.Kom.          M              1990        S12
# 37888                Hardana Gunarto          F              1982        B14
# 37897         drg. Zahra Nashiruddin          F              1976         1T
#
#                         corridorName  direction tapInStops   tapInStopsName  \
# 5               Cibubur - Balai Kota        0.0    B00127P         Benhil 3
# 8            Bekasi Barat - Kuningan        1.0    B00795P         Imperium
# 60     Palem Semi - Bundaran Senayan        1.0    B00589P      GBK Pintu 7
# 70              Cibubur - Balai Kota        0.0    B02408P     Menara Astra
# 117    Palem Semi - Bundaran Senayan        1.0    B00808P          Islamic
# ...                              ...        ...        ...              ...
# 37854             Cibubur - Kuningan        1.0    B00596P   Gedung Granadi
# 37878      Cinere - Bundaran Senayan        0.0    B06642P      Mega Cinere
# 37879        BSD Serpong - Fatmawati        1.0    B04581P  Sbr. Versailles
# 37888        Bekasi Barat - Kuningan        0.0    B00664P   GOR Sumantri 2
# 37897           Cibubur - Balai Kota        1.0    B02873P    Plaza Sentral
#
#        tapInStopsLat  tapInStopsLon  stopStartSeq            tapInTime  \
# 5          -6.216010      106.81632             3  2023-04-03 05:08:01
# 8          -6.210363      106.83059             1  2023-04-03 06:01:44
# 60         -6.222095      106.80861             3  2023-04-03 05:43:48
# 70         -6.207361      106.82190             7  2023-04-03 05:57:55
# 117        -6.228521      106.61473            10  2023-04-03 06:37:27
# ...              ...            ...           ...                  ...
# 37854      -6.231311      106.83301            11  2023-04-03 17:56:55
# 37878      -6.333340      106.78282             4  2023-04-16 07:59:08
# 37879      -6.308522      106.67339             3  2023-04-07 09:28:01
# 37888      -6.221038      106.83189            11  2023-04-05 09:30:00
# 37897      -6.216247      106.81676            12  2023-04-04 10:29:47
#
#       tapOutStops  tapOutStopsName  tapOutStopsLat  tapOutStopsLon  \
# 5         B00694P      Grand Sahid       -6.210975       106.82059
# 8         B01853P     Kayuringin 2       -6.245948       106.99247
# 60        B02556P     Palem Semi 1       -6.218812       106.61807
# 70        B02420P   Menara Thamrin       -6.185275       106.82291
# 117       B02557P     Palem Semi 2       -6.220361       106.61649
# ...           ...              ...             ...             ...
# 37854     B00226P  Buperta Cibubur       -6.370321       106.89628
# 37878     B00378P      FX Sudirman       -6.225532       106.80370
# 37879     B05701P        Term. BSD       -6.306375       106.68536
# 37888     B02411P      Menara Duta       -6.208617       106.82986
# 37897     B00226P  Buperta Cibubur       -6.370321       106.89628
#
#        stopEndSeq           tapOutTime  payAmount             composite_key
# 5             6.0  2023-04-03 05:52:25    20000.0  2251412124634980_B00127P
# 8            16.0  2023-04-03 06:51:12    20000.0  6510013988638519_B00795P
# 60           14.0  2023-04-03 06:09:12    20000.0     4290559479079_B00589P
# 70           13.0                  NaN    20000.0  3549158005951908_B02408P
# 117          12.0  2023-04-03 07:20:36    20000.0     4709994160903_B00808P
# ...           ...                  ...        ...                       ...
# 37854        18.0  2023-04-03 18:21:26    20000.0  3553882732550120_B00596P
# 37878         7.0  2023-04-16 10:58:11    20000.0    36067042340502_B06642P
# 37879         4.0  2023-04-07 10:43:46    20000.0    30480183587078_B04581P
# 37888        14.0  2023-04-05 11:58:54    20000.0  6585885975007109_B00664P
# 37897        14.0  2023-04-04 13:27:25    20000.0   213159426675861_B02873P
#
# [1742 rows x 23 columns]

# %% [markdown]
# for the remaining data which is NA, i will fill it using the normal price of 3500 rupiah

# %%
tj['payAmount'].fillna(3500, inplace=True)

# %% [markdown]
# # **Data Handling of Time**

# %% [markdown]
# In the data there is 2 columns containing Time information, for example the value inside 1 cell would be like this: 2023-04-03 05:08:01.
#
# For better data analysis and finding pattern, this kind of format is not manageable and doesn't give much insight. First of all, all the data inside our DataFrame is taken on transaction that happens in april 2023 so we dont need the month or the year of the format. we only need the dates and hour. Secondly it will be better to analyze the data not just by dates, but also by what day it is because there is usually a pattern showing how the same day have the same amount of users. that means there will be a new columns of day. And lastly, the hour and minutes of the time format doesn't have much function if we don't compare it from the first time the customer tapIn until the customer tapOut, in other words, durations of the Transjakarta usage. so there will be another columns of duration.

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# Before we start handling Time, i would like to clean the data even more. After a thorough cleaning, there is still a few NA inside corridorName, ID, and tapOutDetails. I have used every possible way to my current knowledge to fill the NA and can't find any other way to fill the remaining missing data except for the columns of TapOutTime. Because of that, I will be using DROPNA for the remaining columns missing data.

# %%
tj.dropna(subset='corridorID', inplace = True)

# %%
tj.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID             0
# corridorName           0
# direction              0
# tapInStops            22
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops          129
# tapOutStopsName      120
# tapOutStopsLat       120
# tapOutStopsLon       120
# stopEndSeq           120
# tapOutTime          1305
# payAmount              0
# composite_key          0
# dtype: int64

# %%
tj.dropna(subset='tapOutStops', inplace = True)
tj.dropna(subset='tapInStops', inplace = True)

# %%
tj.isna().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID             0
# corridorName           0
# direction              0
# tapInStops             0
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops            0
# tapOutStopsName        0
# tapOutStopsLat         0
# tapOutStopsLon         0
# stopEndSeq             0
# tapOutTime          1185
# payAmount              0
# composite_key          0
# dtype: int64

# %% [markdown]
# we will now convert the stopEndSeq into an integer, we can't do it previously because of the missing values

# %%
tj['stopEndSeq'] = tj['stopEndSeq'].astype(int)

# %% [markdown]
# I will also drop the composite_key columns because we won't be using it anymore

# %%
tj.drop(columns = 'composite_key', inplace = True)

# %% [markdown]
# ### **Changing type to DateTime**

# %%
# Changing the dtype
tj['tapInTime'] = pd.to_datetime(tj['tapInTime'])
tj['tapOutTime'] = pd.to_datetime(tj['tapOutTime'])

# Create new columns
tj['date'] = tj['tapInTime'].dt.strftime('%d')  # Extract the day of the month as "03"
tj['day'] = tj['tapInTime'].dt.strftime('%A')  # Extract the day name like "Monday"
tj['tapInHour'] = tj['tapInTime'].dt.strftime('%H:%M:%S')  # Extract the time as "05:08:01"
tj['tapOutHour'] = tj['tapOutTime'].dt.strftime('%H:%M:%S')

# %%
# Calculate the duration
tj['duration'] = tj['tapOutTime'] - tj['tapInTime']

# Format the duration to show only the time part (HH:MM:SS)
# tj['duration'] = tj['duration'].apply(lambda x: str(x).split(' ')[-1])

# %%
tj[['date', 'day', 'tapInTime','tapOutTime','duration']]
# Out:
#       date        day           tapInTime          tapOutTime        duration
# 0       03     Monday 2023-04-03 05:21:44 2023-04-03 06:00:53 0 days 00:39:09
# 1       03     Monday 2023-04-03 05:42:44 2023-04-03 06:40:01 0 days 00:57:17
# 2       03     Monday 2023-04-03 05:59:06 2023-04-03 06:50:55 0 days 00:51:49
# 3       03     Monday 2023-04-03 05:44:51 2023-04-03 06:28:16 0 days 00:43:25
# 4       03     Monday 2023-04-03 06:17:35 2023-04-03 06:57:03 0 days 00:39:28
# ...    ...        ...                 ...                 ...             ...
# 37895   21     Friday 2023-04-21 18:18:37 2023-04-21 19:55:49 0 days 01:37:12
# 37896   18    Tuesday 2023-04-18 21:52:31 2023-04-18 22:28:22 0 days 00:35:51
# 37897   04    Tuesday 2023-04-04 10:29:47 2023-04-04 13:27:25 0 days 02:57:38
# 37898   15   Saturday 2023-04-15 19:59:26 2023-04-15 20:27:50 0 days 00:28:24
# 37899   12  Wednesday 2023-04-12 21:08:12 2023-04-12 21:34:53 0 days 00:26:41
#
# [36768 rows x 5 columns]

# %% [markdown]
# ### **Filling the remaining missing data**

# %% [markdown]
# Now we can try to fill the remaining missing data in the columns of tapOutTime, we can do it by averaging how long does the bus take to go from one stops to the next stops within the same route. then we can fill the tapOutTime just by adding the average time it takes to go for a single stops, and multiplied it to the total number of stops the users has to go through.

# %%
tj['stopsPassed'] = tj['stopEndSeq'] - tj['stopStartSeq']

# %%
# Making the pivot table to group by corridorID and average by duration per stopsPassed
avgDuration = pd.pivot_table(data = tj,
               index = ['corridorID','stopsPassed'],
               values = 'duration',
               aggfunc= 'mean')

avgDuration.reset_index(inplace=True)

avgDuration['averagePerStops'] = avgDuration['duration'] / avgDuration['stopsPassed']

avgDuration
# Out:
#      corridorID  stopsPassed                  duration  \
# 0             1            1    0 days 01:07:16.500000
# 1             1            2 0 days 01:17:42.794871794
# 2             1            3 0 days 01:19:18.666666666
# 3             1            4           0 days 01:19:58
# 4             1            5 0 days 00:55:50.736842105
# ...         ...          ...                       ...
# 2369        T21            3 0 days 01:26:07.428571428
# 2370        T21            4    0 days 00:58:53.650000
# 2371        T21            5    0 days 01:16:50.600000
# 2372        T21            6           0 days 01:51:07
# 2373        T21           11 0 days 00:35:28.684210526
#
#                averagePerStops
# 0       0 days 01:07:16.500000
# 1    0 days 00:38:51.397435897
# 2    0 days 00:26:26.222222222
# 3       0 days 00:19:59.500000
# 4    0 days 00:11:10.147368421
# ...                        ...
# 2369 0 days 00:28:42.476190476
# 2370    0 days 00:14:43.412500
# 2371    0 days 00:15:22.120000
# 2372 0 days 00:18:31.166666666
# 2373 0 days 00:03:13.516746411
#
# [2374 rows x 4 columns]

# %%
# finding the total average of each corridorID
avgTotal = pd.pivot_table(data = avgDuration,
               index = 'corridorID',
               values = 'averagePerStops',
               aggfunc= 'mean').reset_index()

# Deleting the fractions of seconds & days
avgTotal['averagePerStops'] = avgTotal['averagePerStops'].astype(str).str.split('.').str[0]
#avgTotal['averagePerStops'] = avgTotal['averagePerStops'].apply(lambda x: str(x).split(' ')[-1])
avgTotal['averagePerStops'] = pd.to_timedelta(avgTotal['averagePerStops'])
# avgTotal['averagePerStops'] = pd.to_datetime(avgTotal['averagePerStops'])

avgTotal
# Out:
#     corridorID averagePerStops
# 0            1 0 days 00:19:27
# 1           10 0 days 00:24:03
# 2          10A 0 days 00:34:18
# 3          10B 0 days 00:50:09
# 4          10D 0 days 00:21:40
# ..         ...             ...
# 212        S21 0 days 00:14:20
# 213        S22 0 days 00:27:40
# 214        S31 0 days 00:38:59
# 215        T11 0 days 00:16:19
# 216        T21 0 days 00:25:17
#
# [217 rows x 2 columns]

# %%
# Merge df into tj to get the average duration for each corridorID
tj = tj.merge(avgTotal, on='corridorID', how='left')

# %%
tj.loc[6]
# Out:
# transID                           HEMW326B9N91TV
# payCardID                        213155822653833
# payCardBank                               emoney
# payCardName                R. Devi Hariyah, S.T.
# payCardSex                                     M
# payCardBirthDate                            1974
# corridorID                                JAK.18
# corridorName                 Kalibata - Kuningan
# direction                                    0.0
# tapInStops                               B00243P
# tapInStopsName                   Cervino Village
# tapInStopsLat                          -6.224355
# tapInStopsLon                          106.85165
# stopStartSeq                                  25
# tapInTime                    2023-04-03 06:58:21
# tapOutStops                              B04699P
# tapOutStopsName     Simpang Al Barkah Dr Saharjo
# tapOutStopsLat                         -6.220395
# tapOutStopsLon                         106.84653
# stopEndSeq                                    40
# tapOutTime                                   NaT
# payAmount                                    0.0
# date                                          03
# day                                       Monday
# tapInHour                               06:58:21
# tapOutHour                                   NaN
# duration                                     NaT
# stopsPassed                                   15
# averagePerStops                  0 days 00:11:41
# Name: 6, dtype: object

# %%
# Calculate the filled values for 'time' column
tj['tapOutHour'] = tj.apply(lambda row: row['averagePerStops'] * row['stopsPassed'] if pd.isna(row['tapOutHour']) else row['tapOutHour'], axis=1)

tj['tapOutTime'] = tj.apply(lambda row: row['tapInTime'] + row['tapOutHour'] if pd.isna(row['tapOutTime']) else row['tapOutTime'], axis=1)

# %%
tj['tapInTime'] = pd.to_datetime(tj['tapInTime'], format='0 days %H:%M:%S')
tj['tapOutTime'] = pd.to_datetime(tj['tapOutTime'], format='0 days %H:%M:%S')

# Calculate duration
tj['duration'] = tj['tapOutTime'] - tj['tapInTime']
tj['tapOutHour'] = tj['tapOutTime'].dt.strftime('%H:%M:%S')

# %%
tj['duration'] = tj['duration'].dt.total_seconds()
tj['duration'] = tj['duration'] / 60

# %%
tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          0
# corridorName        0
# direction           0
# tapInStops          0
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         0
# tapOutStopsName     0
# tapOutStopsLat      0
# tapOutStopsLon      0
# stopEndSeq          0
# tapOutTime          0
# payAmount           0
# date                0
# day                 0
# tapInHour           0
# tapOutHour          0
# duration            0
# stopsPassed         0
# averagePerStops     0
# dtype: int64

# %%
tj
# Out:
#               transID            payCardID payCardBank  \
# 0      EIIW227B8L34VB      180062659848800      emoney
# 1      LGXO740D2N47GZ     4885331907664776         dki
# 2      DJWR385V2U57TO     4996225095064169         dki
# 3      JTUZ800U7C86EH         639099174703       flazz
# 4      VMLO535V7F95NJ         570928206772       flazz
# ...               ...                  ...         ...
# 36763  ZWEC949B8Q87QG  4685818286724028395      brizzi
# 36764  YHHK837P6Y95GN     6502902290603767         dki
# 36765  YXPP627N4G95HO      213159426675861      emoney
# 36766  RGVK175U2U98UV      377840859133591      emoney
# 36767  FMZZ963S4B68ZP         501862539795       flazz
#
#                   payCardName payCardSex  payCardBirthDate corridorID  \
# 0              Bajragin Usada          M              2008          5
# 1                Gandi Widodo          F              1997         6C
# 2               Emong Wastuti          F              1992        R1A
# 3                Surya Wacana          F              1978        11D
# 4             Embuh Mardhiyah          M              1982         12
# ...                       ...        ...               ...        ...
# 36763         Kamila Mahendra          F              2004         6B
# 36764            Titi Siregar          M              1974     3C_1.0
# 36765  drg. Zahra Nashiruddin          F              1976         1T
# 36766            Ana Agustina          M              1976     JAK.13
# 36767       drg. Leo Najmudin          F              1985         13
#
#                                    corridorName  direction tapInStops  \
# 0                         Matraman Baru - Ancol        1.0     P00142
# 1      Stasiun Tebet - Karet via Patra Kuningan        0.0    B01963P
# 2                            Pantai Maju - Kota        0.0    B00499P
# 3           Pulo Gebang - Pulo Gadung 2 via PIK        0.0    B05587P
# 4                         Tanjung Priok - Pluit        0.0     P00239
# ...                                         ...        ...        ...
# 36763         Ragunan - MH Thamrin via Semanggi        1.0     P00261
# 36764                    Pinang Ranti - Pramuka        1.0     P00064
# 36765                      Cibubur - Balai Kota        1.0    B02873P
# 36766               Tanah Abang - Jembatan Lima        1.0    B02505P
# 36767                         Ciledug - Tendean        0.0     P00001
#
#                tapInStopsName  tapInStopsLat  tapInStopsLon  stopStartSeq  \
# 0                   Pal Putih      -6.184631      106.84402             7
# 1                  Kemenkes 2      -6.228700      106.83302            13
# 2                Gg. Kunir II      -6.133132      106.81435            38
# 3                Taman Elok 1      -6.195743      106.93526            23
# 4      Sunter Boulevard Barat      -6.149650      106.88900             5
# ...                       ...            ...            ...           ...
# 36763                  Tosari      -6.196892      106.82309             2
# 36764       Garuda Taman Mini      -6.290154      106.88116             1
# 36765           Plaza Sentral      -6.216247      106.81676            12
# 36766          Museum Textile      -6.188656      106.80954            33
# 36767              Adam Malik      -6.236466      106.74786             2
#
#                 tapInTime tapOutStops        tapOutStopsName  tapOutStopsLat  \
# 0     2023-04-03 05:21:44      P00253                Tegalan       -6.203101
# 1     2023-04-03 05:42:44     B03307P    Sampoerna Strategic       -6.217152
# 2     2023-04-03 05:59:06     B04962P  Simpang Kunir Kemukus       -6.133731
# 3     2023-04-03 05:44:51     B03090P      Raya Penggilingan       -6.183068
# 4     2023-04-03 06:17:35      P00098       Kali Besar Barat       -6.135355
# ...                   ...         ...                    ...             ...
# 36763 2023-04-21 18:18:37      P00228                 SMK 57       -6.290967
# 36764 2023-04-18 21:52:31      P00179           Pinang Ranti       -6.291075
# 36765 2023-04-04 10:29:47     B00226P        Buperta Cibubur       -6.370321
# 36766 2023-04-15 19:59:26     B01787P             JPO Blok G       -6.188861
# 36767 2023-04-12 21:08:12      P00106         Kebayoran Lama       -6.238340
#
#        tapOutStopsLon  stopEndSeq          tapOutTime  payAmount date  \
# 0           106.85715          12 2023-04-03 06:00:53     3500.0   03
# 1           106.81892          21 2023-04-03 06:40:01     3500.0   03
# 2           106.81475          39 2023-04-03 06:50:55     3500.0   03
# 3           106.93194          29 2023-04-03 06:28:16     3500.0   03
# 4           106.81143          15 2023-04-03 06:57:03     3500.0   03
# ...               ...         ...                 ...        ...  ...
# 36763       106.82365          13 2023-04-21 19:55:49     3500.0   21
# 36764       106.88634           2 2023-04-18 22:28:22     3500.0   18
# 36765       106.89628          14 2023-04-04 13:27:25    20000.0   04
# 36766       106.81135          34 2023-04-15 20:27:50        0.0   15
# 36767       106.77752           7 2023-04-12 21:34:53     3500.0   12
#
#              day tapInHour tapOutHour    duration  stopsPassed averagePerStops
# 0         Monday  05:21:44   06:00:53   39.150000            5 0 days 00:21:58
# 1         Monday  05:42:44   06:40:01   57.283333            8 0 days 00:22:42
# 2         Monday  05:59:06   06:50:55   51.816667            1 0 days 00:11:43
# 3         Monday  05:44:51   06:28:16   43.416667            6 0 days 00:17:27
# 4         Monday  06:17:35   06:57:03   39.466667           10 0 days 00:22:16
# ...          ...       ...        ...         ...          ...             ...
# 36763     Friday  18:18:37   19:55:49   97.200000           11 0 days 00:20:44
# 36764    Tuesday  21:52:31   22:28:22   35.850000            1 0 days 00:07:45
# 36765    Tuesday  10:29:47   13:27:25  177.633333            2 0 days 00:27:31
# 36766   Saturday  19:59:26   20:27:50   28.400000            1 0 days 00:17:05
# 36767  Wednesday  21:08:12   21:34:53   26.683333            5 0 days 00:21:58
#
# [36768 rows x 29 columns]

# %%
tj.to_csv('transjakarta_clean.csv', index=False)

# %% [markdown]
# # **3. Data Analysis**
# *next file...*
